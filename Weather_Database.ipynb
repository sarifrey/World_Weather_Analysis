# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Step 3 Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Step 4 get the nearest city using the citipy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 727

# %%
# Step 5 perform an API call with the OpenWeatherMap
import requests
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Step 6 Retrieve the following information from the API call:Latitude and longitude, Maximum temperature, Percent humidity
# Percent humidity, Wind speed,Weather description

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
# Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
# Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]

# Append the city information into city_data list.
        city_data.append({"City": city.title(),
              "Country": city_country,
              "Lat": city_lat,
              "Lng": city_lng,
              "Max Temp": city_max_temp,
              "Humidity": city_humidity,
              "Cloudiness": city_clouds,
              "Wind Speed": city_wind,
              "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | azangaro
# Processing Record 5 of Set 1 | haines junction
# Processing Record 6 of Set 1 | oistins
# Processing Record 7 of Set 1 | camingawan
# Processing Record 8 of Set 1 | cariati
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | najran
# Processing Record 12 of Set 1 | college
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | castro
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | huesca
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | ziarat
# Processing Record 24 of Set 1 | harper
# Processing Record 25 of Set 1 | neuquen
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | gushikawa
# Processing Record 28 of Set 1 | kiunga
# Processing Record 29 of Set 1 | majene
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | shelburne
# Processing Record 32 of Set 1 | port keats
# Processing Record 33 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | lompoc
# Processing Record 36 of Set 1 | kodinar
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | torbay
# Processing Record 40 of Set 1 | nikolskoye
# Processing Record 41 of Set 1 | tuatapere
# Processing Record 42 of Set 1 | aracataca
# Processing Record 43 of Set 1 | oranjemund
# Processing Record 44 of Set 1 | cherskiy
# Processing Record 45 of Set 1 | hasaki
# Processing Record 46 of Set 1 | luderitz
# Processing Record 47 of Set 1 | mahebourg
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 50 of Set 1 | tiarei
# Processing Record 1 of Set 2 | saskylakh
# Processing Record 2 of Set 2 | okmulgee
# Processing Record 3 of Set 2 | deputatskiy
# Processing Record 4 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 2 | huarmey
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | waipawa
# Processing Record 8 of Set 2 | sokoni
# Processing Record 9 of Set 2 | bathurst
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | camacupa
# Processing Record 12 of Set 2 | vryburg
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | khatanga
# Processing Record 19 of Set 2 | freeport
# Processing Record 20 of Set 2 | lavrentiya
# Processing Record 21 of Set 2 | chuy
# Processing Record 22 of Set 2 | hami
# Processing Record 23 of Set 2 | escanaba
# Processing Record 24 of Set 2 | koubia
# Processing Record 25 of Set 2 | bambous virieux
# Processing Record 26 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | punta arenas
# Processing Record 29 of Set 2 | buala
# Processing Record 30 of Set 2 | caravelas
# Processing Record 31 of Set 2 | venado tuerto
# Processing Record 32 of Set 2 | tuktoyaktuk
# Processing Record 33 of Set 2 | temir
# Processing Record 34 of Set 2 | burkhala
# City not found. Skipping...
# Processing Record 35 of Set 2 | halifax
# Processing Record 36 of Set 2 | bandarbeyla
# Processing Record 37 of Set 2 | zhezkazgan
# Processing Record 38 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 2 | dolinsk
# Processing Record 40 of Set 2 | tura
# Processing Record 41 of Set 2 | luau
# Processing Record 42 of Set 2 | portland
# Processing Record 43 of Set 2 | ilhabela
# Processing Record 44 of Set 2 | airai
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | mbekenyera
# Processing Record 47 of Set 2 | aden
# Processing Record 48 of Set 2 | balabac
# Processing Record 49 of Set 2 | flinders
# Processing Record 50 of Set 2 | krasnyy chikoy
# Processing Record 1 of Set 3 | jamestown
# Processing Record 2 of Set 3 | port macquarie
# Processing Record 3 of Set 3 | sorochinsk
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 3 | esperance
# Processing Record 6 of Set 3 | jinxiang
# Processing Record 7 of Set 3 | scarborough
# Processing Record 8 of Set 3 | corrales
# Processing Record 9 of Set 3 | laguna
# Processing Record 10 of Set 3 | okhotsk
# Processing Record 11 of Set 3 | provideniya
# Processing Record 12 of Set 3 | alofi
# Processing Record 13 of Set 3 | lorengau
# Processing Record 14 of Set 3 | korla
# Processing Record 15 of Set 3 | ponta do sol
# Processing Record 16 of Set 3 | khandyga
# Processing Record 17 of Set 3 | beringovskiy
# Processing Record 18 of Set 3 | zlobin
# Processing Record 19 of Set 3 | nokaneng
# Processing Record 20 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 3 | hohhot
# Processing Record 22 of Set 3 | atbasar
# Processing Record 23 of Set 3 | atessa
# Processing Record 24 of Set 3 | vanimo
# Processing Record 25 of Set 3 | saint quentin
# City not found. Skipping...
# Processing Record 26 of Set 3 | ambilobe
# Processing Record 27 of Set 3 | klaksvik
# Processing Record 28 of Set 3 | thompson
# Processing Record 29 of Set 3 | redding
# Processing Record 30 of Set 3 | eyl
# Processing Record 31 of Set 3 | del rio
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | maldonado
# Processing Record 34 of Set 3 | diamantino
# Processing Record 35 of Set 3 | nome
# Processing Record 36 of Set 3 | kaitangata
# Processing Record 37 of Set 3 | wisconsin rapids
# Processing Record 38 of Set 3 | havre-saint-pierre
# Processing Record 39 of Set 3 | jarabacoa
# Processing Record 40 of Set 3 | faanui
# Processing Record 41 of Set 3 | kropotkin
# Processing Record 42 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 3 | isiolo
# Processing Record 45 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 46 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 3 | hit
# Processing Record 48 of Set 3 | dubti
# Processing Record 49 of Set 3 | yellowknife
# Processing Record 50 of Set 3 | cidreira
# Processing Record 1 of Set 4 | dum duma
# Processing Record 2 of Set 4 | saint-philippe
# Processing Record 3 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 4 | tabou
# Processing Record 5 of Set 4 | kismayo
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | hithadhoo
# Processing Record 8 of Set 4 | nioro
# Processing Record 9 of Set 4 | victoria
# Processing Record 10 of Set 4 | sadovoye
# Processing Record 11 of Set 4 | riyadh
# Processing Record 12 of Set 4 | severodvinsk
# Processing Record 13 of Set 4 | buraydah
# Processing Record 14 of Set 4 | hay river
# Processing Record 15 of Set 4 | byron bay
# Processing Record 16 of Set 4 | carnarvon
# Processing Record 17 of Set 4 | atar
# Processing Record 18 of Set 4 | tezu
# Processing Record 19 of Set 4 | palasa
# Processing Record 20 of Set 4 | gamba
# Processing Record 21 of Set 4 | san patricio
# Processing Record 22 of Set 4 | chuka
# Processing Record 23 of Set 4 | itamaraca
# Processing Record 24 of Set 4 | boundiali
# Processing Record 25 of Set 4 | porto nacional
# Processing Record 26 of Set 4 | sangmelima
# Processing Record 27 of Set 4 | coihaique
# Processing Record 28 of Set 4 | gat
# Processing Record 29 of Set 4 | gore
# Processing Record 30 of Set 4 | hobart
# Processing Record 31 of Set 4 | beni
# Processing Record 32 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 33 of Set 4 | azad shahr
# Processing Record 34 of Set 4 | cam ranh
# Processing Record 35 of Set 4 | mount gambier
# Processing Record 36 of Set 4 | revda
# Processing Record 37 of Set 4 | paamiut
# Processing Record 38 of Set 4 | kavieng
# Processing Record 39 of Set 4 | mopti
# Processing Record 40 of Set 4 | walvis bay
# Processing Record 41 of Set 4 | rabat
# Processing Record 42 of Set 4 | norman wells
# Processing Record 43 of Set 4 | nakamura
# Processing Record 44 of Set 4 | alexandria
# Processing Record 45 of Set 4 | salalah
# Processing Record 46 of Set 4 | constitucion
# Processing Record 47 of Set 4 | yining
# Processing Record 48 of Set 4 | cabo san lucas
# Processing Record 49 of Set 4 | la roche-sur-yon
# Processing Record 50 of Set 4 | malaya vishera
# Processing Record 1 of Set 5 | catalina
# Processing Record 2 of Set 5 | meadow lake
# Processing Record 3 of Set 5 | saurimo
# Processing Record 4 of Set 5 | labuan
# Processing Record 5 of Set 5 | ravar
# Processing Record 6 of Set 5 | new norfolk
# Processing Record 7 of Set 5 | nishihara
# Processing Record 8 of Set 5 | mogadishu
# Processing Record 9 of Set 5 | bengkulu
# Processing Record 10 of Set 5 | seoul
# Processing Record 11 of Set 5 | vysokogornyy
# Processing Record 12 of Set 5 | sur
# Processing Record 13 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 5 | martapura
# Processing Record 15 of Set 5 | hambantota
# Processing Record 16 of Set 5 | kysyl-syr
# Processing Record 17 of Set 5 | kruisfontein
# Processing Record 18 of Set 5 | bubaque
# Processing Record 19 of Set 5 | odweyne
# Processing Record 20 of Set 5 | sola
# Processing Record 21 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 5 | kavaratti
# Processing Record 25 of Set 5 | georgetown
# Processing Record 26 of Set 5 | fortuna
# Processing Record 27 of Set 5 | mana
# Processing Record 28 of Set 5 | guiglo
# Processing Record 29 of Set 5 | zhanjiang
# Processing Record 30 of Set 5 | amahai
# Processing Record 31 of Set 5 | pucallpa
# Processing Record 32 of Set 5 | sept-iles
# Processing Record 33 of Set 5 | saldanha
# Processing Record 34 of Set 5 | nisia floresta
# Processing Record 35 of Set 5 | calbuco
# Processing Record 36 of Set 5 | tiksi
# Processing Record 37 of Set 5 | meulaboh
# Processing Record 38 of Set 5 | carutapera
# Processing Record 39 of Set 5 | impfondo
# Processing Record 40 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 5 | sohbatpur
# Processing Record 42 of Set 5 | narsaq
# Processing Record 43 of Set 5 | wencheng
# Processing Record 44 of Set 5 | san cristobal
# Processing Record 45 of Set 5 | suzaka
# Processing Record 46 of Set 5 | yaan
# Processing Record 47 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 5 | celestun
# Processing Record 49 of Set 5 | antalaha
# Processing Record 50 of Set 5 | bethel
# Processing Record 1 of Set 6 | mosquera
# Processing Record 2 of Set 6 | novokuznetsk
# Processing Record 3 of Set 6 | kilindoni
# Processing Record 4 of Set 6 | tigil
# Processing Record 5 of Set 6 | shimoda
# Processing Record 6 of Set 6 | sayat
# Processing Record 7 of Set 6 | samarkand
# Processing Record 8 of Set 6 | san rafael
# Processing Record 9 of Set 6 | marsh harbour
# Processing Record 10 of Set 6 | dingle
# Processing Record 11 of Set 6 | karpathos
# Processing Record 12 of Set 6 | malakal
# Processing Record 13 of Set 6 | puerto escondido
# Processing Record 14 of Set 6 | asfi
# Processing Record 15 of Set 6 | qaanaaq
# Processing Record 16 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 6 | moron
# Processing Record 18 of Set 6 | vallenar
# Processing Record 19 of Set 6 | dana point
# Processing Record 20 of Set 6 | araouane
# Processing Record 21 of Set 6 | de-kastri
# Processing Record 22 of Set 6 | gaoual
# Processing Record 23 of Set 6 | makung
# City not found. Skipping...
# Processing Record 24 of Set 6 | kedrovyy
# Processing Record 25 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 6 | east london
# Processing Record 27 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 6 | faya
# Processing Record 29 of Set 6 | maxixe
# Processing Record 30 of Set 6 | russkiy kameshkir
# Processing Record 31 of Set 6 | ermelo
# Processing Record 32 of Set 6 | stawell
# Processing Record 33 of Set 6 | sitrah
# Processing Record 34 of Set 6 | ler
# Processing Record 35 of Set 6 | guerrero negro
# Processing Record 36 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 37 of Set 6 | hofn
# Processing Record 38 of Set 6 | ostrovnoy
# Processing Record 39 of Set 6 | port hardy
# Processing Record 40 of Set 6 | inuvik
# Processing Record 41 of Set 6 | murdochville
# Processing Record 42 of Set 6 | marawi
# Processing Record 43 of Set 6 | viedma
# Processing Record 44 of Set 6 | hervey bay
# Processing Record 45 of Set 6 | skjervoy
# Processing Record 46 of Set 6 | hualmay
# Processing Record 47 of Set 6 | talara
# Processing Record 48 of Set 6 | havelock
# Processing Record 49 of Set 6 | tomatlan
# Processing Record 50 of Set 6 | brae
# Processing Record 1 of Set 7 | serra
# Processing Record 2 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 7 | san clemente
# Processing Record 4 of Set 7 | oyem
# Processing Record 5 of Set 7 | pedernales
# Processing Record 6 of Set 7 | jiquilisco
# Processing Record 7 of Set 7 | aykhal
# Processing Record 8 of Set 7 | vanavara
# Processing Record 9 of Set 7 | flagstaff
# Processing Record 10 of Set 7 | vardo
# Processing Record 11 of Set 7 | padang
# Processing Record 12 of Set 7 | pisco
# Processing Record 13 of Set 7 | coruripe
# Processing Record 14 of Set 7 | rio gallegos
# Processing Record 15 of Set 7 | sitka
# Processing Record 16 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 7 | minnedosa
# Processing Record 18 of Set 7 | marshalltown
# Processing Record 19 of Set 7 | te anau
# Processing Record 20 of Set 7 | port blair
# Processing Record 21 of Set 7 | pacific grove
# Processing Record 22 of Set 7 | khotynets
# Processing Record 23 of Set 7 | puerto del rosario
# Processing Record 24 of Set 7 | mattawa
# Processing Record 25 of Set 7 | cayenne
# Processing Record 26 of Set 7 | buta
# Processing Record 27 of Set 7 | ulladulla
# Processing Record 28 of Set 7 | altay
# Processing Record 29 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 7 | leningradskiy
# Processing Record 31 of Set 7 | cubuk
# Processing Record 32 of Set 7 | lebu
# Processing Record 33 of Set 7 | taltal
# Processing Record 34 of Set 7 | tasiilaq
# Processing Record 35 of Set 7 | la ronge
# Processing Record 36 of Set 7 | mezen
# Processing Record 37 of Set 7 | assiniboia
# Processing Record 38 of Set 7 | ciudad bolivar
# Processing Record 39 of Set 7 | zhigansk
# Processing Record 40 of Set 7 | ambon
# Processing Record 41 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 42 of Set 7 | chiredzi
# Processing Record 43 of Set 7 | meiktila
# Processing Record 44 of Set 7 | rabo de peixe
# Processing Record 45 of Set 7 | lindi
# Processing Record 46 of Set 7 | iglas
# Processing Record 47 of Set 7 | pangoa
# Processing Record 48 of Set 7 | santarem
# Processing Record 49 of Set 7 | fez
# Processing Record 50 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 1 of Set 8 | vao
# Processing Record 2 of Set 8 | pitimbu
# Processing Record 3 of Set 8 | baon
# Processing Record 4 of Set 8 | sistranda
# Processing Record 5 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 8 | houma
# Processing Record 7 of Set 8 | sao joao da barra
# Processing Record 8 of Set 8 | usogorsk
# Processing Record 9 of Set 8 | parabel
# Processing Record 10 of Set 8 | port hedland
# Processing Record 11 of Set 8 | souillac
# Processing Record 12 of Set 8 | saint-pierre
# Processing Record 13 of Set 8 | christchurch
# Processing Record 14 of Set 8 | isangel
# Processing Record 15 of Set 8 | san quintin
# Processing Record 16 of Set 8 | sansai
# City not found. Skipping...
# Processing Record 17 of Set 8 | kesennuma
# City not found. Skipping...
# Processing Record 18 of Set 8 | pevek
# Processing Record 19 of Set 8 | egvekinot
# Processing Record 20 of Set 8 | aras
# Processing Record 21 of Set 8 | araguacu
# Processing Record 22 of Set 8 | vila
# Processing Record 23 of Set 8 | vila velha
# Processing Record 24 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 25 of Set 8 | labuhan
# Processing Record 26 of Set 8 | ucluelet
# Processing Record 27 of Set 8 | taoudenni
# Processing Record 28 of Set 8 | xining
# Processing Record 29 of Set 8 | svetlogorsk
# Processing Record 30 of Set 8 | yar-sale
# Processing Record 31 of Set 8 | manjacaze
# Processing Record 32 of Set 8 | trairi
# Processing Record 33 of Set 8 | rivne
# Processing Record 34 of Set 8 | kutum
# Processing Record 35 of Set 8 | kerema
# Processing Record 36 of Set 8 | ponta delgada
# Processing Record 37 of Set 8 | alvdal
# Processing Record 38 of Set 8 | perene
# Processing Record 39 of Set 8 | russell
# Processing Record 40 of Set 8 | herat
# Processing Record 41 of Set 8 | diglur
# Processing Record 42 of Set 8 | prince rupert
# Processing Record 43 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 8 | natal
# Processing Record 45 of Set 8 | colares
# Processing Record 46 of Set 8 | hella
# Processing Record 47 of Set 8 | northam
# Processing Record 48 of Set 8 | along
# Processing Record 49 of Set 8 | arshan
# Processing Record 50 of Set 8 | ozark
# Processing Record 1 of Set 9 | codrington
# Processing Record 2 of Set 9 | tamandare
# Processing Record 3 of Set 9 | male
# Processing Record 4 of Set 9 | kondoa
# Processing Record 5 of Set 9 | poum
# Processing Record 6 of Set 9 | mabaruma
# Processing Record 7 of Set 9 | sarkand
# Processing Record 8 of Set 9 | baherden
# Processing Record 9 of Set 9 | sorland
# Processing Record 10 of Set 9 | ilulissat
# Processing Record 11 of Set 9 | mahibadhoo
# Processing Record 12 of Set 9 | aklavik
# Processing Record 13 of Set 9 | xiamen
# Processing Record 14 of Set 9 | ancud
# Processing Record 15 of Set 9 | lucea
# Processing Record 16 of Set 9 | nacozari
# Processing Record 17 of Set 9 | porto empedocle
# Processing Record 18 of Set 9 | katsuura
# Processing Record 19 of Set 9 | lingao
# Processing Record 20 of Set 9 | fort-shevchenko
# Processing Record 21 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 22 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 23 of Set 9 | itoman
# Processing Record 24 of Set 9 | kishanganj
# Processing Record 25 of Set 9 | turukhansk
# Processing Record 26 of Set 9 | bathsheba
# Processing Record 27 of Set 9 | igrim
# Processing Record 28 of Set 9 | bor
# Processing Record 29 of Set 9 | the valley
# Processing Record 30 of Set 9 | shaartuz
# City not found. Skipping...
# Processing Record 31 of Set 9 | korem
# Processing Record 32 of Set 9 | ballina
# Processing Record 33 of Set 9 | avera
# Processing Record 34 of Set 9 | imphal
# Processing Record 35 of Set 9 | lazaro cardenas
# Processing Record 36 of Set 9 | sao felix do xingu
# Processing Record 37 of Set 9 | yatou
# Processing Record 38 of Set 9 | kargil
# Processing Record 39 of Set 9 | thunder bay
# Processing Record 40 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 9 | severo-kurilsk
# Processing Record 42 of Set 9 | waddan
# Processing Record 43 of Set 9 | kushima
# Processing Record 44 of Set 9 | beloha
# Processing Record 45 of Set 9 | helong
# Processing Record 46 of Set 9 | hirara
# Processing Record 47 of Set 9 | meinung
# City not found. Skipping...
# Processing Record 48 of Set 9 | burica
# City not found. Skipping...
# Processing Record 49 of Set 9 | kloulklubed
# Processing Record 50 of Set 9 | lamu
# Processing Record 1 of Set 10 | bilibino
# Processing Record 2 of Set 10 | anar darreh
# City not found. Skipping...
# Processing Record 3 of Set 10 | adrar
# Processing Record 4 of Set 10 | saint george
# Processing Record 5 of Set 10 | rock sound
# Processing Record 6 of Set 10 | kasongo-lunda
# Processing Record 7 of Set 10 | cadillac
# Processing Record 8 of Set 10 | grindavik
# Processing Record 9 of Set 10 | mbanza-ngungu
# Processing Record 10 of Set 10 | punto fijo
# Processing Record 11 of Set 10 | novo aripuana
# Processing Record 12 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 13 of Set 10 | dwarka
# Processing Record 14 of Set 10 | sarangani
# Processing Record 15 of Set 10 | kirovskiy
# Processing Record 16 of Set 10 | lagoa
# Processing Record 17 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 18 of Set 10 | okha
# Processing Record 19 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 10 | chikwawa
# Processing Record 21 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 10 | ofunato
# Processing Record 23 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 10 | sambava
# Processing Record 25 of Set 10 | vila franca do campo
# Processing Record 26 of Set 10 | comodoro rivadavia
# Processing Record 27 of Set 10 | richards bay
# Processing Record 28 of Set 10 | cockburn town
# Processing Record 29 of Set 10 | shahr-e babak
# Processing Record 30 of Set 10 | ahipara
# Processing Record 31 of Set 10 | cedral
# Processing Record 32 of Set 10 | haapu
# City not found. Skipping...
# Processing Record 33 of Set 10 | soyo
# Processing Record 34 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 35 of Set 10 | mount pleasant
# Processing Record 36 of Set 10 | amalapuram
# Processing Record 37 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 38 of Set 10 | mandera
# Processing Record 39 of Set 10 | saint-jean-de-luz
# Processing Record 40 of Set 10 | bonthe
# Processing Record 41 of Set 10 | kuusankoski
# Processing Record 42 of Set 10 | rocha
# Processing Record 43 of Set 10 | lima
# Processing Record 44 of Set 10 | kjollefjord
# Processing Record 45 of Set 10 | uray
# Processing Record 46 of Set 10 | cacequi
# Processing Record 47 of Set 10 | camacha
# Processing Record 48 of Set 10 | falaleu
# City not found. Skipping...
# Processing Record 49 of Set 10 | antsohihy
# Processing Record 50 of Set 10 | letterkenny
# Processing Record 1 of Set 11 | sinnamary
# Processing Record 2 of Set 11 | kudahuvadhoo
# Processing Record 3 of Set 11 | san policarpo
# Processing Record 4 of Set 11 | jalu
# Processing Record 5 of Set 11 | nauta
# Processing Record 6 of Set 11 | maketu
# Processing Record 7 of Set 11 | yuncheng
# Processing Record 8 of Set 11 | longyearbyen
# Processing Record 9 of Set 11 | yakeshi
# Processing Record 10 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 11 of Set 11 | dhidhdhoo
# Processing Record 12 of Set 11 | cobija
# Processing Record 13 of Set 11 | sayyan
# Processing Record 14 of Set 11 | inhambane
# Processing Record 15 of Set 11 | voznesenye
# Processing Record 16 of Set 11 | puerto varas
# Processing Record 17 of Set 11 | hovd
# Processing Record 18 of Set 11 | dukat
# Processing Record 19 of Set 11 | mikuni
# Processing Record 20 of Set 11 | antropovo
# Processing Record 21 of Set 11 | santa cruz cabralia
# Processing Record 22 of Set 11 | omboue
# Processing Record 23 of Set 11 | dolores
# Processing Record 24 of Set 11 | vzmorye
# Processing Record 25 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 26 of Set 11 | qasigiannguit
# Processing Record 27 of Set 11 | anloga
# Processing Record 28 of Set 11 | sheridan
# Processing Record 29 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 30 of Set 11 | eau claire
# Processing Record 31 of Set 11 | kutahya
# Processing Record 32 of Set 11 | guamal
# Processing Record 33 of Set 11 | tahoua
# Processing Record 34 of Set 11 | staryy nadym
# Processing Record 35 of Set 11 | erzin
# Processing Record 36 of Set 11 | jumla
# Processing Record 37 of Set 11 | lexington
# Processing Record 38 of Set 11 | maunabo
# Processing Record 39 of Set 11 | purworejo
# Processing Record 40 of Set 11 | svidnik
# Processing Record 41 of Set 11 | progreso
# Processing Record 42 of Set 11 | la libertad
# Processing Record 43 of Set 11 | srandakan
# Processing Record 44 of Set 11 | chapais
# Processing Record 45 of Set 11 | nouadhibou
# Processing Record 46 of Set 11 | moses lake
# Processing Record 47 of Set 11 | dunedin
# Processing Record 48 of Set 11 | geraldton
# Processing Record 49 of Set 11 | matagami
# Processing Record 50 of Set 11 | neiafu
# Processing Record 1 of Set 12 | kyabe
# Processing Record 2 of Set 12 | soja
# Processing Record 3 of Set 12 | we
# City not found. Skipping...
# Processing Record 4 of Set 12 | isla mujeres
# Processing Record 5 of Set 12 | umarkhed
# Processing Record 6 of Set 12 | bulungu
# Processing Record 7 of Set 12 | tilichiki
# Processing Record 8 of Set 12 | dali
# Processing Record 9 of Set 12 | tela
# Processing Record 10 of Set 12 | homa bay
# Processing Record 11 of Set 12 | whittlesea
# Processing Record 12 of Set 12 | san nicolas
# Processing Record 13 of Set 12 | touros
# Processing Record 14 of Set 12 | guasdualito
# Processing Record 15 of Set 12 | kem
# Processing Record 16 of Set 12 | okhansk
# Processing Record 17 of Set 12 | alegrete
# Processing Record 18 of Set 12 | pihani
# Processing Record 19 of Set 12 | lasa
# Processing Record 20 of Set 12 | ribeira brava
# Processing Record 21 of Set 12 | kidal
# Processing Record 22 of Set 12 | san luis
# Processing Record 23 of Set 12 | kargopol
# Processing Record 24 of Set 12 | biloela
# Processing Record 25 of Set 12 | iqaluit
# Processing Record 26 of Set 12 | mecca
# Processing Record 27 of Set 12 | sigli
# Processing Record 28 of Set 12 | sidi ali
# Processing Record 29 of Set 12 | nanortalik
# Processing Record 30 of Set 12 | esterhazy
# Processing Record 31 of Set 12 | krasnyy klyuch
# Processing Record 32 of Set 12 | sobolevo
# Processing Record 33 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 12 | wanning
# Processing Record 35 of Set 12 | kirksville
# Processing Record 36 of Set 12 | xichang
# Processing Record 37 of Set 12 | asau
# Processing Record 38 of Set 12 | auki
# Processing Record 39 of Set 12 | huangyan
# Processing Record 40 of Set 12 | kahului
# Processing Record 41 of Set 12 | weihe
# Processing Record 42 of Set 12 | atambua
# Processing Record 43 of Set 12 | kieta
# Processing Record 44 of Set 12 | sao filipe
# Processing Record 45 of Set 12 | cabinda
# Processing Record 46 of Set 12 | portree
# Processing Record 47 of Set 12 | pamanukan
# Processing Record 48 of Set 12 | rawson
# Processing Record 49 of Set 12 | quatre cocos
# Processing Record 50 of Set 12 | axim
# Processing Record 1 of Set 13 | kourou
# Processing Record 2 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 3 of Set 13 | burns lake
# Processing Record 4 of Set 13 | naples
# Processing Record 5 of Set 13 | sisophon
# Processing Record 6 of Set 13 | kizner
# Processing Record 7 of Set 13 | sandpoint
# Processing Record 8 of Set 13 | tinos
# Processing Record 9 of Set 13 | bara
# Processing Record 10 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 13 | karratha
# Processing Record 12 of Set 13 | vysokopillya
# Processing Record 13 of Set 13 | luganville
# Processing Record 14 of Set 13 | rawah
# Processing Record 15 of Set 13 | zhenlai
# Processing Record 16 of Set 13 | chimbote
# Processing Record 17 of Set 13 | shubarshi
# Processing Record 18 of Set 13 | kenai
# Processing Record 19 of Set 13 | vershino-shakhtaminskiy
# Processing Record 20 of Set 13 | ornskoldsvik
# Processing Record 21 of Set 13 | tapiramuta
# Processing Record 22 of Set 13 | tamworth
# Processing Record 23 of Set 13 | korhogo
# Processing Record 24 of Set 13 | prince george
# Processing Record 25 of Set 13 | alice springs
# Processing Record 26 of Set 13 | awbari
# Processing Record 27 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 28 of Set 13 | naze
# Processing Record 29 of Set 13 | leh
# Processing Record 30 of Set 13 | cravo norte
# Processing Record 31 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 32 of Set 13 | rameshki
# Processing Record 33 of Set 13 | kalmunai
# Processing Record 34 of Set 13 | kitui
# Processing Record 35 of Set 13 | lao cai
# Processing Record 36 of Set 13 | kikwit
# Processing Record 37 of Set 13 | cankuzo
# Processing Record 38 of Set 13 | kyren
# Processing Record 39 of Set 13 | opuwo
# Processing Record 40 of Set 13 | angra
# City not found. Skipping...
# Processing Record 41 of Set 13 | bojnurd
# Processing Record 42 of Set 13 | dudinka
# Processing Record 43 of Set 13 | burnie
# Processing Record 44 of Set 13 | glendive
# Processing Record 45 of Set 13 | jaipur
# Processing Record 46 of Set 13 | salekhard
# Processing Record 47 of Set 13 | karamken
# City not found. Skipping...
# Processing Record 48 of Set 13 | muli
# Processing Record 49 of Set 13 | batangafo
# Processing Record 50 of Set 13 | talaya
# Processing Record 1 of Set 14 | emerald
# Processing Record 2 of Set 14 | kawhia
# Processing Record 3 of Set 14 | nakusp
# Processing Record 4 of Set 14 | zaltan
# Processing Record 5 of Set 14 | namibe
# Processing Record 6 of Set 14 | port moresby
# Processing Record 7 of Set 14 | baykit
# Processing Record 8 of Set 14 | srednekolymsk
# Processing Record 9 of Set 14 | tres lagoas
# Processing Record 10 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 14 | half moon bay
# Processing Record 12 of Set 14 | pareora
# Processing Record 13 of Set 14 | pilna
# Processing Record 14 of Set 14 | qaqortoq
# Processing Record 15 of Set 14 | gravdal
# Processing Record 16 of Set 14 | fairbanks
# Processing Record 17 of Set 14 | talnakh
# Processing Record 18 of Set 14 | vallentuna
# Processing Record 19 of Set 14 | verkhoyansk
# Processing Record 20 of Set 14 | strehaia
# Processing Record 21 of Set 14 | broome
# Processing Record 22 of Set 14 | quarai
# Processing Record 23 of Set 14 | port-gentil
# Processing Record 24 of Set 14 | preston
# Processing Record 25 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 14 | gavle
# Processing Record 27 of Set 14 | chepareria
# Processing Record 28 of Set 14 | manica
# Processing Record 29 of Set 14 | ondjiva
# Processing Record 30 of Set 14 | platteville
# Processing Record 31 of Set 14 | catuday
# Processing Record 32 of Set 14 | young
# Processing Record 33 of Set 14 | abidjan
# Processing Record 34 of Set 14 | ola
# Processing Record 35 of Set 14 | sioux lookout
# Processing Record 36 of Set 14 | kulhudhuffushi
# Processing Record 37 of Set 14 | vilyuysk
# Processing Record 38 of Set 14 | ikere
# Processing Record 39 of Set 14 | zlitan
# Processing Record 40 of Set 14 | livingston
# Processing Record 41 of Set 14 | nsunga
# Processing Record 42 of Set 14 | lakatoro
# Processing Record 43 of Set 14 | lashio
# Processing Record 44 of Set 14 | radhanpur
# Processing Record 45 of Set 14 | mata
# Processing Record 46 of Set 14 | kamaishi
# Processing Record 47 of Set 14 | sfantu gheorghe
# Processing Record 48 of Set 14 | saint anthony
# Processing Record 49 of Set 14 | hoyanger
# Processing Record 50 of Set 14 | nemuro
# Processing Record 1 of Set 15 | havoysund
# Processing Record 2 of Set 15 | hobyo
# Processing Record 3 of Set 15 | sulangan
# Processing Record 4 of Set 15 | pietarsaari
# Processing Record 5 of Set 15 | angoche
# Processing Record 6 of Set 15 | linchuan
# City not found. Skipping...
# Processing Record 7 of Set 15 | rognan
# Processing Record 8 of Set 15 | coreau
# Processing Record 9 of Set 15 | dukuhturi
# Processing Record 10 of Set 15 | ahuimanu
# Processing Record 11 of Set 15 | todos santos
# Processing Record 12 of Set 15 | waingapu
# Processing Record 13 of Set 15 | biak
# Processing Record 14 of Set 15 | san isidro
# Processing Record 15 of Set 15 | severnyy
# Processing Record 16 of Set 15 | campbeltown
# Processing Record 17 of Set 15 | tiznit
# Processing Record 18 of Set 15 | ansalta
# Processing Record 19 of Set 15 | peterhead
# Processing Record 20 of Set 15 | newnan
# Processing Record 21 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 15 | shingu
# Processing Record 23 of Set 15 | mehamn
# Processing Record 24 of Set 15 | kisanga
# Processing Record 25 of Set 15 | coahuayana
# Processing Record 26 of Set 15 | zaysan
# Processing Record 27 of Set 15 | paredon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Step 7 add the data to a new DataFrame. 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Avarua      CK -21.2078 -159.7750     75.25        88          40
# 1            Vaini      TO -21.2000 -175.2000     75.56        83          80
# 2         Azangaro      PE -14.9167  -70.2167     59.83        17          68
# 3  Haines Junction      CA  60.7522 -137.5108     58.95        55          99
# 4          Oistins      BB  13.0667  -59.5333     84.29        79          20
# 5       Camingawan      PH   9.9036  122.8417     76.82        93          77
# 6          Cariati      IT  39.4922   16.9594     81.27        55           0
# 7          Rikitea      PF -23.1203 -134.9692     70.88        67          25
# 8       Bredasdorp      ZA -34.5322   20.0403     45.72        93         100
# 9           Najran      SA  17.4924   44.1277     86.65        34          89
#
#    Wind Speed Current Description
# 0        4.61    scattered clouds
# 1        4.36       broken clouds
# 2       12.21       broken clouds
# 3        3.44     overcast clouds
# 4       11.50          few clouds
# 5        4.63       broken clouds
# 6        3.51           clear sky
# 7        5.03    scattered clouds
# 8        3.44     overcast clouds
# 9        1.54     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

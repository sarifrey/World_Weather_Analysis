# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Step 3 Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Step 4 get the nearest city using the citipy module
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
#for coordinate in coordinates:
    #print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          #citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Step 5 perform an API call with the OpenWeatherMap
import requests
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Step 6 Retrieve the following information from the API call:Latitude and longitude, Maximum temperature, Percent humidity
# Percent humidity, Wind speed,Weather description

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
try:
    # Parse the JSON and retrieve data.
    city_weather = requests.get(city_url).json()
    # Parse out the needed data.
    city_country = city_weather["sys"]["country"]
    city_lat = city_weather["coord"]["lat"]
    city_lng = city_weather["coord"]["lon"]
    city_max_temp = city_weather["main"]["temp_max"]
    city_humidity = city_weather["main"]["humidity"]
    city_clouds = city_weather["clouds"]["all"]
    city_wind = city_weather["wind"]["speed"]
    city_description = city_weather["weather"]["description"]

    # Convert the date to ISO standard.
    #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
    city_data.append({"City": city.title(),
                      "Country": city_country,
                      "Lat": city_lat,
                      "Lng": city_lng,
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                      "Current Description": city_description})

# If an error is experienced, skip the city.
except:
    print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# Processing Record 2 of Set 1 | codrington
# Processing Record 3 of Set 1 | mtwara
# Processing Record 4 of Set 1 | ancud
# Processing Record 5 of Set 1 | laibin
# Processing Record 6 of Set 1 | cape coast
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | margate
# Processing Record 9 of Set 1 | cherskiy
# Processing Record 10 of Set 1 | kawardha
# Processing Record 11 of Set 1 | neuquen
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | talnakh
# Processing Record 14 of Set 1 | longyearbyen
# Processing Record 15 of Set 1 | portland
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | bolungarvik
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | clinton
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | cidreira
# Processing Record 23 of Set 1 | laguna
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | sentyabrskiy
# Processing Record 26 of Set 1 | namatanai
# Processing Record 27 of Set 1 | lebu
# Processing Record 28 of Set 1 | dekar
# Processing Record 29 of Set 1 | mullaitivu
# Processing Record 30 of Set 1 | shingu
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | tsihombe
# Processing Record 33 of Set 1 | ilulissat
# Processing Record 34 of Set 1 | takaka
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | victoria
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | port augusta
# Processing Record 42 of Set 1 | narsaq
# Processing Record 43 of Set 1 | cayenne
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | caravelas
# Processing Record 47 of Set 1 | ayan
# Processing Record 48 of Set 1 | fare
# Processing Record 49 of Set 1 | iquique
# Processing Record 50 of Set 1 | ola
# Processing Record 1 of Set 2 | bubaque
# Processing Record 2 of Set 2 | kruisfontein
# Processing Record 3 of Set 2 | omboue
# Processing Record 4 of Set 2 | bang yai
# Processing Record 5 of Set 2 | stutterheim
# Processing Record 6 of Set 2 | kudat
# Processing Record 7 of Set 2 | clifton
# Processing Record 8 of Set 2 | saskylakh
# Processing Record 9 of Set 2 | amderma
# Processing Record 10 of Set 2 | cabo san lucas
# Processing Record 11 of Set 2 | davis
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | matara
# Processing Record 14 of Set 2 | los llanos de aridane
# Processing Record 15 of Set 2 | mount isa
# Processing Record 16 of Set 2 | gaogou
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | verkhnevilyuysk
# Processing Record 19 of Set 2 | khonuu
# Processing Record 20 of Set 2 | belushya guba
# Processing Record 21 of Set 2 | saleaula
# Processing Record 22 of Set 2 | port elizabeth
# Processing Record 23 of Set 2 | aksu
# Processing Record 24 of Set 2 | dieppe
# Processing Record 25 of Set 2 | east london
# Processing Record 26 of Set 2 | rikitea
# Processing Record 27 of Set 2 | tiznit
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | paamiut
# Processing Record 30 of Set 2 | barentsburg
# Processing Record 31 of Set 2 | terrace
# Processing Record 32 of Set 2 | saint-philippe
# Processing Record 33 of Set 2 | walvis bay
# Processing Record 34 of Set 2 | lajosmizse
# Processing Record 35 of Set 2 | upernavik
# Processing Record 36 of Set 2 | kungurtug
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | guerrero negro
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | san cristobal
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | whitehorse
# Processing Record 43 of Set 2 | chuy
# Processing Record 44 of Set 2 | namibe
# Processing Record 45 of Set 2 | kumluca
# Processing Record 46 of Set 2 | mitu
# Processing Record 47 of Set 2 | kaitangata
# Processing Record 48 of Set 2 | vao
# Processing Record 49 of Set 2 | qaanaaq
# Processing Record 50 of Set 2 | maningrida
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | rincon
# Processing Record 3 of Set 3 | la plaine
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | port alfred
# Processing Record 6 of Set 3 | san andres
# Processing Record 7 of Set 3 | yichun
# Processing Record 8 of Set 3 | saint-ambroise
# Processing Record 9 of Set 3 | port hardy
# Processing Record 10 of Set 3 | barrow
# Processing Record 11 of Set 3 | willowmore
# Processing Record 12 of Set 3 | yellowknife
# Processing Record 13 of Set 3 | torbay
# Processing Record 14 of Set 3 | melo
# Processing Record 15 of Set 3 | esperance
# Processing Record 16 of Set 3 | kasempa
# Processing Record 17 of Set 3 | mar del plata
# Processing Record 18 of Set 3 | sur
# Processing Record 19 of Set 3 | new norfolk
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | garissa
# Processing Record 22 of Set 3 | moose factory
# Processing Record 23 of Set 3 | tsabong
# Processing Record 24 of Set 3 | bambous virieux
# Processing Record 25 of Set 3 | nome
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 | lorengau
# Processing Record 28 of Set 3 | ruatoria
# Processing Record 29 of Set 3 | saldanha
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | castro
# Processing Record 32 of Set 3 | georgetown
# Processing Record 33 of Set 3 | saint george
# Processing Record 34 of Set 3 | aklavik
# Processing Record 35 of Set 3 | fevralsk
# Processing Record 36 of Set 3 | salto
# Processing Record 37 of Set 3 | fort nelson
# Processing Record 38 of Set 3 | vestmannaeyjar
# Processing Record 39 of Set 3 | verkhovazhye
# Processing Record 40 of Set 3 | illoqqortoormiut
# Processing Record 41 of Set 3 | ulaanbaatar
# Processing Record 42 of Set 3 | wilmington
# Processing Record 43 of Set 3 | nenjiang
# Processing Record 44 of Set 3 | launceston
# Processing Record 45 of Set 3 | hami
# Processing Record 46 of Set 3 | callaguip
# Processing Record 47 of Set 3 | roseburg
# Processing Record 48 of Set 3 | rio gallegos
# Processing Record 49 of Set 3 | cuiaba
# Processing Record 50 of Set 3 | grindavik
# Processing Record 1 of Set 4 | mbanza-ngungu
# Processing Record 2 of Set 4 | faya
# Processing Record 3 of Set 4 | baicheng
# Processing Record 4 of Set 4 | tula
# Processing Record 5 of Set 4 | nalhati
# Processing Record 6 of Set 4 | san buenaventura
# Processing Record 7 of Set 4 | sitka
# Processing Record 8 of Set 4 | sturgeon bay
# Processing Record 9 of Set 4 | kharp
# Processing Record 10 of Set 4 | sorland
# Processing Record 11 of Set 4 | barra dos coqueiros
# Processing Record 12 of Set 4 | babahoyo
# Processing Record 13 of Set 4 | lazaro cardenas
# Processing Record 14 of Set 4 | sovetskiy
# Processing Record 15 of Set 4 | bukama
# Processing Record 16 of Set 4 | sarandi
# Processing Record 17 of Set 4 | bairiki
# Processing Record 18 of Set 4 | coihaique
# Processing Record 19 of Set 4 | pyaozerskiy
# Processing Record 20 of Set 4 | bengkulu
# Processing Record 21 of Set 4 | anadyr
# Processing Record 22 of Set 4 | teguldet
# Processing Record 23 of Set 4 | mys shmidta
# Processing Record 24 of Set 4 | altamira
# Processing Record 25 of Set 4 | mahebourg
# Processing Record 26 of Set 4 | carnarvon
# Processing Record 27 of Set 4 | jian
# Processing Record 28 of Set 4 | salto de agua
# Processing Record 29 of Set 4 | monrovia
# Processing Record 30 of Set 4 | weihe
# Processing Record 31 of Set 4 | fortuna
# Processing Record 32 of Set 4 | qingyuan
# Processing Record 33 of Set 4 | vostok
# Processing Record 34 of Set 4 | tiksi
# Processing Record 35 of Set 4 | guaratuba
# Processing Record 36 of Set 4 | rocha
# Processing Record 37 of Set 4 | norman wells
# Processing Record 38 of Set 4 | kuusamo
# Processing Record 39 of Set 4 | naze
# Processing Record 40 of Set 4 | mersing
# Processing Record 41 of Set 4 | korla
# Processing Record 42 of Set 4 | karwar
# Processing Record 43 of Set 4 | namtsy
# Processing Record 44 of Set 4 | meyungs
# Processing Record 45 of Set 4 | iqaluit
# Processing Record 46 of Set 4 | veraval
# Processing Record 47 of Set 4 | panjwin
# Processing Record 48 of Set 4 | gravdal
# Processing Record 49 of Set 4 | nishihara
# Processing Record 50 of Set 4 | makarov
# Processing Record 1 of Set 5 | sungaipenuh
# Processing Record 2 of Set 5 | waingapu
# Processing Record 3 of Set 5 | acatlan
# Processing Record 4 of Set 5 | deputatskiy
# Processing Record 5 of Set 5 | ghanzi
# Processing Record 6 of Set 5 | constitucion
# Processing Record 7 of Set 5 | sao filipe
# Processing Record 8 of Set 5 | kasongo
# Processing Record 9 of Set 5 | clyde river
# Processing Record 10 of Set 5 | tulun
# Processing Record 11 of Set 5 | tuktoyaktuk
# Processing Record 12 of Set 5 | cefalu
# Processing Record 13 of Set 5 | hervey bay
# Processing Record 14 of Set 5 | luderitz
# Processing Record 15 of Set 5 | flinders
# Processing Record 16 of Set 5 | zbarazh
# Processing Record 17 of Set 5 | coquimbo
# Processing Record 18 of Set 5 | araripe
# Processing Record 19 of Set 5 | sakakah
# Processing Record 20 of Set 5 | sao joao da barra
# Processing Record 21 of Set 5 | baft
# Processing Record 22 of Set 5 | nampula
# Processing Record 23 of Set 5 | juneau
# Processing Record 24 of Set 5 | ngukurr
# Processing Record 25 of Set 5 | adiake
# Processing Record 26 of Set 5 | hasaki
# Processing Record 27 of Set 5 | sinnamary
# Processing Record 28 of Set 5 | tres arroyos
# Processing Record 29 of Set 5 | stokmarknes
# Processing Record 30 of Set 5 | dolbeau
# Processing Record 31 of Set 5 | nelson bay
# Processing Record 32 of Set 5 | hithadhoo
# Processing Record 33 of Set 5 | roald
# Processing Record 34 of Set 5 | kodiak
# Processing Record 35 of Set 5 | chuka
# Processing Record 36 of Set 5 | henties bay
# Processing Record 37 of Set 5 | san jose del golfo
# Processing Record 38 of Set 5 | luebo
# Processing Record 39 of Set 5 | larap
# Processing Record 40 of Set 5 | hualmay
# Processing Record 41 of Set 5 | farmington
# Processing Record 42 of Set 5 | katsuura
# Processing Record 43 of Set 5 | bakchar
# Processing Record 44 of Set 5 | pisco
# Processing Record 45 of Set 5 | hendek
# Processing Record 46 of Set 5 | maumere
# Processing Record 47 of Set 5 | durusu
# Processing Record 48 of Set 5 | marcona
# Processing Record 49 of Set 5 | srivardhan
# Processing Record 50 of Set 5 | samusu
# Processing Record 1 of Set 6 | peniche
# Processing Record 2 of Set 6 | barguzin
# Processing Record 3 of Set 6 | bilibino
# Processing Record 4 of Set 6 | acapulco
# Processing Record 5 of Set 6 | montemor-o-novo
# Processing Record 6 of Set 6 | mumford
# Processing Record 7 of Set 6 | tasiilaq
# Processing Record 8 of Set 6 | perth
# Processing Record 9 of Set 6 | port lincoln
# Processing Record 10 of Set 6 | quatre cocos
# Processing Record 11 of Set 6 | linchuan
# Processing Record 12 of Set 6 | vila franca do campo
# Processing Record 13 of Set 6 | pevek
# Processing Record 14 of Set 6 | san jose
# Processing Record 15 of Set 6 | broome
# Processing Record 16 of Set 6 | kanel
# Processing Record 17 of Set 6 | atikokan
# Processing Record 18 of Set 6 | uruzgan
# Processing Record 19 of Set 6 | yuzhno-yeniseyskiy
# Processing Record 20 of Set 6 | kamenskoye
# Processing Record 21 of Set 6 | mozhaysk
# Processing Record 22 of Set 6 | takoradi
# Processing Record 23 of Set 6 | churumuco
# Processing Record 24 of Set 6 | celestun
# Processing Record 25 of Set 6 | vila velha
# Processing Record 26 of Set 6 | mandalgovi
# Processing Record 27 of Set 6 | port hedland
# Processing Record 28 of Set 6 | pahrump
# Processing Record 29 of Set 6 | el faiyum
# Processing Record 30 of Set 6 | mason city
# Processing Record 31 of Set 6 | sidrolandia
# Processing Record 32 of Set 6 | yenagoa
# Processing Record 33 of Set 6 | vaitupu
# Processing Record 34 of Set 6 | pundaguitan
# Processing Record 35 of Set 6 | palana
# Processing Record 36 of Set 6 | conceicao do araguaia
# Processing Record 37 of Set 6 | westport
# Processing Record 38 of Set 6 | touros
# Processing Record 39 of Set 6 | muttupet
# Processing Record 40 of Set 6 | forestville
# Processing Record 41 of Set 6 | dezful
# Processing Record 42 of Set 6 | dudinka
# Processing Record 43 of Set 6 | opuwo
# Processing Record 44 of Set 6 | puerto pailas
# Processing Record 45 of Set 6 | severo-kurilsk
# Processing Record 46 of Set 6 | puerto madryn
# Processing Record 47 of Set 6 | bilma
# Processing Record 48 of Set 6 | ellisras
# Processing Record 49 of Set 6 | grand-santi
# Processing Record 50 of Set 6 | jinan
# Processing Record 1 of Set 7 | lavrentiya
# Processing Record 2 of Set 7 | xam nua
# Processing Record 3 of Set 7 | harper
# Processing Record 4 of Set 7 | banswada
# Processing Record 5 of Set 7 | mudgee
# Processing Record 6 of Set 7 | bac lieu
# Processing Record 7 of Set 7 | avera
# Processing Record 8 of Set 7 | mecca
# Processing Record 9 of Set 7 | dandong
# Processing Record 10 of Set 7 | halalo
# Processing Record 11 of Set 7 | east saint louis
# Processing Record 12 of Set 7 | hay river
# Processing Record 13 of Set 7 | klaksvik
# Processing Record 14 of Set 7 | port blair
# Processing Record 15 of Set 7 | dingle
# Processing Record 16 of Set 7 | attawapiskat
# Processing Record 17 of Set 7 | vardo
# Processing Record 18 of Set 7 | uwayl
# Processing Record 19 of Set 7 | aflao
# Processing Record 20 of Set 7 | biak
# Processing Record 21 of Set 7 | emerald
# Processing Record 22 of Set 7 | kirovskiy
# Processing Record 23 of Set 7 | vegreville
# Processing Record 24 of Set 7 | cururupu
# Processing Record 25 of Set 7 | itamaraca
# Processing Record 26 of Set 7 | zabaykalsk
# Processing Record 27 of Set 7 | bauchi
# Processing Record 28 of Set 7 | acarau
# Processing Record 29 of Set 7 | viedma
# Processing Record 30 of Set 7 | nanga eboko
# Processing Record 31 of Set 7 | bethel
# Processing Record 32 of Set 7 | kavieng
# Processing Record 33 of Set 7 | nykobing
# Processing Record 34 of Set 7 | saint-lo
# Processing Record 35 of Set 7 | nalut
# Processing Record 36 of Set 7 | leh
# Processing Record 37 of Set 7 | necochea
# Processing Record 38 of Set 7 | romny
# Processing Record 39 of Set 7 | smithers
# Processing Record 40 of Set 7 | polunochnoye
# Processing Record 41 of Set 7 | ferrol
# Processing Record 42 of Set 7 | geraldton
# Processing Record 43 of Set 7 | higuey
# Processing Record 44 of Set 7 | kahului
# Processing Record 45 of Set 7 | talara
# Processing Record 46 of Set 7 | faanui
# Processing Record 47 of Set 7 | okato
# Processing Record 48 of Set 7 | hohhot
# Processing Record 49 of Set 7 | zhezkazgan
# Processing Record 50 of Set 7 | san policarpo
# Processing Record 1 of Set 8 | ravar
# Processing Record 2 of Set 8 | doha
# Processing Record 3 of Set 8 | khatanga
# Processing Record 4 of Set 8 | carballo
# Processing Record 5 of Set 8 | balikpapan
# Processing Record 6 of Set 8 | linhares
# Processing Record 7 of Set 8 | kalmunai
# Processing Record 8 of Set 8 | acuna
# Processing Record 9 of Set 8 | xichang
# Processing Record 10 of Set 8 | guadalupe y calvo
# Processing Record 11 of Set 8 | tidore
# Processing Record 12 of Set 8 | nouadhibou
# Processing Record 13 of Set 8 | udachnyy
# Processing Record 14 of Set 8 | urumqi
# Processing Record 15 of Set 8 | dharchula
# Processing Record 16 of Set 8 | gigmoto
# Processing Record 17 of Set 8 | santa isabel
# Processing Record 18 of Set 8 | melfi
# Processing Record 19 of Set 8 | malpe
# Processing Record 20 of Set 8 | grand gaube
# Processing Record 21 of Set 8 | nuuk
# Processing Record 22 of Set 8 | fort morgan
# Processing Record 23 of Set 8 | vigrestad
# Processing Record 24 of Set 8 | dori
# Processing Record 25 of Set 8 | ostrovnoy
# Processing Record 26 of Set 8 | saint-paul
# Processing Record 27 of Set 8 | galle
# Processing Record 28 of Set 8 | palm coast
# Processing Record 29 of Set 8 | ixtapa
# Processing Record 30 of Set 8 | adrar
# Processing Record 31 of Set 8 | kolokani
# Processing Record 32 of Set 8 | santo domingo
# Processing Record 33 of Set 8 | feldkirchen an der donau
# Processing Record 34 of Set 8 | nyurba
# Processing Record 35 of Set 8 | lompoc
# Processing Record 36 of Set 8 | georgiyevka
# Processing Record 37 of Set 8 | olafsvik
# Processing Record 38 of Set 8 | tateyama
# Processing Record 39 of Set 8 | bathsheba
# Processing Record 40 of Set 8 | ngunguru
# Processing Record 41 of Set 8 | guantanamo
# Processing Record 42 of Set 8 | ust-kamchatsk
# Processing Record 43 of Set 8 | sechura
# Processing Record 44 of Set 8 | kitimat
# Processing Record 45 of Set 8 | bargal
# Processing Record 46 of Set 8 | santiago del estero
# Processing Record 47 of Set 8 | moranbah
# Processing Record 48 of Set 8 | halifax
# Processing Record 49 of Set 8 | alampur
# Processing Record 50 of Set 8 | tay ninh
# Processing Record 1 of Set 9 | ciumani
# Processing Record 2 of Set 9 | kirakira
# Processing Record 3 of Set 9 | mao
# Processing Record 4 of Set 9 | aguilas
# Processing Record 5 of Set 9 | puerto del rosario
# Processing Record 6 of Set 9 | panguna
# Processing Record 7 of Set 9 | kalininsk
# Processing Record 8 of Set 9 | haines junction
# Processing Record 9 of Set 9 | boyolangu
# Processing Record 10 of Set 9 | kamenka
# Processing Record 11 of Set 9 | karkaralinsk
# Processing Record 12 of Set 9 | maarianhamina
# Processing Record 13 of Set 9 | aswan
# Processing Record 14 of Set 9 | jacareacanga
# Processing Record 15 of Set 9 | beyneu
# Processing Record 16 of Set 9 | abu kamal
# Processing Record 17 of Set 9 | isangel
# Processing Record 18 of Set 9 | lolua
# Processing Record 19 of Set 9 | ilebo
# Processing Record 20 of Set 9 | stornoway
# Processing Record 21 of Set 9 | luganville
# Processing Record 22 of Set 9 | zurrieq
# Processing Record 23 of Set 9 | olinda
# Processing Record 24 of Set 9 | goderich
# Processing Record 25 of Set 9 | kuryk
# Processing Record 26 of Set 9 | alofi
# Processing Record 27 of Set 9 | carutapera
# Processing Record 28 of Set 9 | malanje
# Processing Record 29 of Set 9 | mbandaka
# Processing Record 30 of Set 9 | masuguru
# Processing Record 31 of Set 9 | eyl
# Processing Record 32 of Set 9 | verkhoyansk
# Processing Record 33 of Set 9 | dali
# Processing Record 34 of Set 9 | beidao
# Processing Record 35 of Set 9 | quesnel
# Processing Record 36 of Set 9 | lenggries
# Processing Record 37 of Set 9 | batagay
# Processing Record 38 of Set 9 | vilyuysk
# Processing Record 39 of Set 9 | galiwinku
# Processing Record 40 of Set 9 | kimbe
# Processing Record 41 of Set 9 | krasnoarmeysk
# Processing Record 42 of Set 9 | leningradskiy
# Processing Record 43 of Set 9 | japura
# Processing Record 44 of Set 9 | naryan-mar
# Processing Record 45 of Set 9 | kyabe
# Processing Record 46 of Set 9 | banagher
# Processing Record 47 of Set 9 | altay
# Processing Record 48 of Set 9 | usinsk
# Processing Record 49 of Set 9 | tiarei
# Processing Record 50 of Set 9 | chagda
# Processing Record 1 of Set 10 | grand river south east
# Processing Record 2 of Set 10 | kharan
# Processing Record 3 of Set 10 | gopalpur
# Processing Record 4 of Set 10 | college
# Processing Record 5 of Set 10 | stepnyak
# Processing Record 6 of Set 10 | auki
# Processing Record 7 of Set 10 | talcahuano
# Processing Record 8 of Set 10 | kolosovka
# Processing Record 9 of Set 10 | santa rosa
# Processing Record 10 of Set 10 | husavik
# Processing Record 11 of Set 10 | sept-iles
# Processing Record 12 of Set 10 | roma
# Processing Record 13 of Set 10 | salinas
# Processing Record 14 of Set 10 | lata
# Processing Record 15 of Set 10 | luanda
# Processing Record 16 of Set 10 | payson
# Processing Record 17 of Set 10 | aguimes
# Processing Record 18 of Set 10 | nantucket
# Processing Record 19 of Set 10 | tanout
# Processing Record 20 of Set 10 | karatau
# Processing Record 21 of Set 10 | cervo
# Processing Record 22 of Set 10 | lexington park
# Processing Record 23 of Set 10 | beringovskiy
# Processing Record 24 of Set 10 | den helder
# Processing Record 25 of Set 10 | berdigestyakh
# Processing Record 26 of Set 10 | odweyne
# Processing Record 27 of Set 10 | grajewo
# Processing Record 28 of Set 10 | quime
# Processing Record 29 of Set 10 | sohag
# Processing Record 30 of Set 10 | kaduy
# Processing Record 31 of Set 10 | buariki
# Processing Record 32 of Set 10 | palmer
# Processing Record 33 of Set 10 | berdavan
# Processing Record 34 of Set 10 | alekseyevsk
# Processing Record 35 of Set 10 | severodvinsk
# Processing Record 36 of Set 10 | gamba
# Processing Record 37 of Set 10 | nador
# Processing Record 38 of Set 10 | almaznyy
# Processing Record 39 of Set 10 | saint-denis
# Processing Record 40 of Set 10 | rawannawi
# Processing Record 41 of Set 10 | tari
# Processing Record 42 of Set 10 | williams lake
# Processing Record 43 of Set 10 | kurumkan
# Processing Record 44 of Set 10 | erzin
# Processing Record 45 of Set 10 | shenzhen
# Processing Record 46 of Set 10 | tecoanapa
# Processing Record 47 of Set 10 | marv dasht
# Processing Record 48 of Set 10 | jasper
# Processing Record 49 of Set 10 | pochutla
# Processing Record 50 of Set 10 | senneterre
# Processing Record 1 of Set 11 | mehriz
# Processing Record 2 of Set 11 | uray
# Processing Record 3 of Set 11 | taltal
# Processing Record 4 of Set 11 | bull savanna
# Processing Record 5 of Set 11 | inhambane
# Processing Record 6 of Set 11 | saint-pierre
# Processing Record 7 of Set 11 | nazilli
# Processing Record 8 of Set 11 | doctor juan leon mallorquin
# Processing Record 9 of Set 11 | phuket
# Processing Record 10 of Set 11 | ahipara
# Processing Record 11 of Set 11 | tacoronte
# Processing Record 12 of Set 11 | caernarfon
# Processing Record 13 of Set 11 | treinta y tres
# Processing Record 14 of Set 11 | korcula
# Processing Record 15 of Set 11 | shchelyayur
# Processing Record 16 of Set 11 | sayyan
# Processing Record 17 of Set 11 | lasa
# Processing Record 18 of Set 11 | wladyslawowo
# Processing Record 19 of Set 11 | louisbourg
# Processing Record 20 of Set 11 | woodward
# Processing Record 21 of Set 11 | airai
# Processing Record 22 of Set 11 | plettenberg bay
# Processing Record 23 of Set 11 | kautokeino
# Processing Record 24 of Set 11 | ambovombe
# Processing Record 25 of Set 11 | mangai
# Processing Record 26 of Set 11 | hirara
# Processing Record 27 of Set 11 | villacarrillo
# Processing Record 28 of Set 11 | wicklow
# Processing Record 29 of Set 11 | samarai
# Processing Record 30 of Set 11 | loei
# Processing Record 31 of Set 11 | nassjo
# Processing Record 32 of Set 11 | poum
# Processing Record 33 of Set 11 | babati
# Processing Record 34 of Set 11 | yekaterinovka
# Processing Record 35 of Set 11 | yumen
# Processing Record 36 of Set 11 | cherepovets
# Processing Record 37 of Set 11 | pandan
# Processing Record 38 of Set 11 | santarem
# Processing Record 39 of Set 11 | marrakesh
# Processing Record 40 of Set 11 | galesong
# Processing Record 41 of Set 11 | hihifo
# Processing Record 42 of Set 11 | abha
# Processing Record 43 of Set 11 | rogovatoye
# Processing Record 44 of Set 11 | riyadh
# Processing Record 45 of Set 11 | camocim
# Processing Record 46 of Set 11 | dumas
# Processing Record 47 of Set 11 | weihai
# Processing Record 48 of Set 11 | santa lucia
# Processing Record 49 of Set 11 | kloulklubed
# Processing Record 50 of Set 11 | puerto colombia
# Processing Record 1 of Set 12 | rognan
# Processing Record 2 of Set 12 | ashqelon
# Processing Record 3 of Set 12 | hudiksvall
# Processing Record 4 of Set 12 | pionerskiy
# Processing Record 5 of Set 12 | curaca
# Processing Record 6 of Set 12 | tabas
# Processing Record 7 of Set 12 | san carlos de bariloche
# Processing Record 8 of Set 12 | fomboni
# Processing Record 9 of Set 12 | miri
# Processing Record 10 of Set 12 | mayo
# Processing Record 11 of Set 12 | salo
# Processing Record 12 of Set 12 | rio cuarto
# Processing Record 13 of Set 12 | ojinaga
# Processing Record 14 of Set 12 | mezen
# Processing Record 15 of Set 12 | dublin
# Processing Record 16 of Set 12 | male
# Processing Record 17 of Set 12 | esperanza
# Processing Record 18 of Set 12 | umzimvubu
# Processing Record 19 of Set 12 | havre-saint-pierre
# Processing Record 20 of Set 12 | gotha
# Processing Record 21 of Set 12 | tshela
# Processing Record 22 of Set 12 | we
# Processing Record 23 of Set 12 | egvekinot
# Processing Record 24 of Set 12 | cap-aux-meules
# Processing Record 25 of Set 12 | solnechnyy
# Processing Record 26 of Set 12 | sanchursk
# Processing Record 27 of Set 12 | nizhneyansk
# Processing Record 28 of Set 12 | araouane
# Processing Record 29 of Set 12 | kabo
# Processing Record 30 of Set 12 | buraydah
# Processing Record 31 of Set 12 | chauk
# Processing Record 32 of Set 12 | waipawa
# Processing Record 33 of Set 12 | kaisiadorys
# Processing Record 34 of Set 12 | bogovina
# Processing Record 35 of Set 12 | alice springs
# Processing Record 36 of Set 12 | huarmey
# Processing Record 37 of Set 12 | nizhneudinsk
# Processing Record 38 of Set 12 | bossembele
# Processing Record 39 of Set 12 | pringsewu
# Processing Record 40 of Set 12 | belmonte
# Processing Record 41 of Set 12 | yanchukan
# Processing Record 42 of Set 12 | newport
# Processing Record 43 of Set 12 | mulege
# Processing Record 44 of Set 12 | mastic beach
# Processing Record 45 of Set 12 | laje
# Processing Record 46 of Set 12 | kerema
# Processing Record 47 of Set 12 | yumbe
# Processing Record 48 of Set 12 | massakory
# Processing Record 49 of Set 12 | cairns
# Processing Record 50 of Set 12 | northam
# Processing Record 1 of Set 13 | mangrol
# Processing Record 2 of Set 13 | dhanwar
# Processing Record 3 of Set 13 | basco
# Processing Record 4 of Set 13 | praia
# Processing Record 5 of Set 13 | banda aceh
# Processing Record 6 of Set 13 | pangnirtung
# Processing Record 7 of Set 13 | bandarbeyla
# Processing Record 8 of Set 13 | saint-georges
# Processing Record 9 of Set 13 | kaeo
# Processing Record 10 of Set 13 | sao joao de pirabas
# Processing Record 11 of Set 13 | melilla
# Processing Record 12 of Set 13 | bukachacha
# Processing Record 13 of Set 13 | sao francisco de assis
# Processing Record 14 of Set 13 | nanortalik
# Processing Record 15 of Set 13 | maniitsoq
# Processing Record 16 of Set 13 | lensk
# Processing Record 17 of Set 13 | cavalcante
# Processing Record 18 of Set 13 | san rafael
# Processing Record 19 of Set 13 | ambilobe
# Processing Record 20 of Set 13 | elizabeth city
# Processing Record 21 of Set 13 | bourail
# Processing Record 22 of Set 13 | san patricio
# Processing Record 23 of Set 13 | itarema
# Processing Record 24 of Set 13 | gumdag
# Processing Record 25 of Set 13 | montepuez
# Processing Record 26 of Set 13 | bantry
# Processing Record 27 of Set 13 | kuching
# Processing Record 28 of Set 13 | tuatapere
# Processing Record 29 of Set 13 | tilichiki
# Processing Record 30 of Set 13 | hirtshals
# Processing Record 31 of Set 13 | dombarovskiy
# Processing Record 32 of Set 13 | pleshanovo
# Processing Record 33 of Set 13 | natal
# Processing Record 34 of Set 13 | sol-iletsk
# Processing Record 35 of Set 13 | barreirinhas
# Processing Record 36 of Set 13 | tabuk
# Processing Record 37 of Set 13 | bulgan
# Processing Record 38 of Set 13 | nemuro
# Processing Record 39 of Set 13 | oranjemund
# Processing Record 40 of Set 13 | palabuhanratu
# Processing Record 41 of Set 13 | mirandola
# Processing Record 42 of Set 13 | makat
# Processing Record 43 of Set 13 | kuri
# Processing Record 44 of Set 13 | annonay
# Processing Record 45 of Set 13 | manta
# Processing Record 46 of Set 13 | montrose
# Processing Record 47 of Set 13 | colon
# Processing Record 48 of Set 13 | culebra
# Processing Record 49 of Set 13 | baiyin
# Processing Record 50 of Set 13 | corn island
# Processing Record 1 of Set 14 | hiriyur
# Processing Record 2 of Set 14 | labutta
# Processing Record 3 of Set 14 | palaikastron
# Processing Record 4 of Set 14 | karaton
# Processing Record 5 of Set 14 | ko samui
# Processing Record 6 of Set 14 | temaraia
# Processing Record 7 of Set 14 | maun
# Processing Record 8 of Set 14 | trelew
# Processing Record 9 of Set 14 | zhenlai
# Processing Record 10 of Set 14 | virginia beach
# Processing Record 11 of Set 14 | yar-sale
# Processing Record 12 of Set 14 | pocatello
# Processing Record 13 of Set 14 | aguililla
# Processing Record 14 of Set 14 | semey
# Processing Record 15 of Set 14 | vizinga
# Processing Record 16 of Set 14 | businga
# Processing Record 17 of Set 14 | kieta
# Processing Record 18 of Set 14 | shieli
# Processing Record 19 of Set 14 | vestmanna
# Processing Record 20 of Set 14 | llata
# Processing Record 21 of Set 14 | alta
# Processing Record 22 of Set 14 | tubuala
# Processing Record 23 of Set 14 | fengcheng
# Processing Record 24 of Set 14 | tremedal
# Processing Record 25 of Set 14 | rawson
# Processing Record 26 of Set 14 | teknaf
# Processing Record 27 of Set 14 | sayalgudi
# Processing Record 28 of Set 14 | port macquarie
# Processing Record 29 of Set 14 | grand centre
# Processing Record 30 of Set 14 | presidente epitacio
# Processing Record 31 of Set 14 | kualakapuas
# Processing Record 32 of Set 14 | pitimbu
# Processing Record 33 of Set 14 | kushmurun
# Processing Record 34 of Set 14 | pierre
# Processing Record 35 of Set 14 | glenwood springs
# Processing Record 36 of Set 14 | port-gentil
# Processing Record 37 of Set 14 | portales
# Processing Record 38 of Set 14 | matagami
# Processing Record 39 of Set 14 | puerto leguizamo
# Processing Record 40 of Set 14 | ulaangom
# Processing Record 41 of Set 14 | jalu
# Processing Record 42 of Set 14 | cartaya
# Processing Record 43 of Set 14 | hunza
# Processing Record 44 of Set 14 | mattru
# Processing Record 45 of Set 14 | rochester
# Processing Record 46 of Set 14 | araxa
# Processing Record 47 of Set 14 | haibowan
# Processing Record 48 of Set 14 | kikwit
# Processing Record 49 of Set 14 | alexandria
# Processing Record 50 of Set 14 | grahamstown
# Processing Record 1 of Set 15 | yatou
# Processing Record 2 of Set 15 | two hills
# Processing Record 3 of Set 15 | bahia blanca
# Processing Record 4 of Set 15 | hambantota
# Processing Record 5 of Set 15 | longlac
# Processing Record 6 of Set 15 | prince albert
# Processing Record 7 of Set 15 | karamay
# Processing Record 8 of Set 15 | nikolayevsk-na-amure
# Processing Record 9 of Set 15 | mayumba
# Processing Record 10 of Set 15 | zhigansk
# Processing Record 11 of Set 15 | cap malheureux
# Processing Record 12 of Set 15 | labuan
# Processing Record 13 of Set 15 | komsomolskiy
# Processing Record 14 of Set 15 | salalah
# Processing Record 15 of Set 15 | fort smith
# Processing Record 16 of Set 15 | truth or consequences
# Processing Record 17 of Set 15 | yanji
# Processing Record 18 of Set 15 | niteroi
# Processing Record 19 of Set 15 | wynyard
# Processing Record 20 of Set 15 | evensk
# Processing Record 21 of Set 15 | ituacu
# Processing Record 22 of Set 15 | ventspils
# Processing Record 23 of Set 15 | malanville
# Processing Record 24 of Set 15 | phulabani
# Processing Record 25 of Set 15 | sabang
# Processing Record 26 of Set 15 | poltavka
# Processing Record 27 of Set 15 | teahupoo
# Processing Record 28 of Set 15 | plaster rock
# Processing Record 29 of Set 15 | maringa
# Processing Record 30 of Set 15 | satitoa
# Processing Record 31 of Set 15 | houma
# Processing Record 32 of Set 15 | lazarev
# Processing Record 33 of Set 15 | nichinan
# Processing Record 34 of Set 15 | maldonado
# Processing Record 35 of Set 15 | tarauaca
# Processing Record 36 of Set 15 | batemans bay
# Processing Record 37 of Set 15 | prince rupert
# Processing Record 38 of Set 15 | viesite
# Processing Record 39 of Set 15 | morro bay
# Processing Record 40 of Set 15 | khani
# Processing Record 41 of Set 15 | fairbanks
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Step 7 add the data to a new DataFrame. 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

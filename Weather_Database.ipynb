# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Step 3 Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Step 4 get the nearest city using the citipy module
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
#for coordinate in coordinates:
    #print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          #citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 711

# %%
# Step 5 perform an API call with the OpenWeatherMap
import requests
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4a37097f6bcfc1547f4922d88c28cdce

# %%
# Step 6 Retrieve the following information from the API call:Latitude and longitude, Maximum temperature, Percent humidity
# Percent humidity, Wind speed,Weather description

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
# Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
# Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]

# Append the city information into city_data list.
        city_data.append({"City": city.title(),
              "Country": city_country,
              "Lat": city_lat,
              "Lng": city_lng,
              "Max Temp": city_max_temp,
              "Humidity": city_humidity,
              "Cloudiness": city_clouds,
              "Wind Speed": city_wind,
              "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | east london
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | deputatskiy
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | sept-iles
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | saint george
# Processing Record 14 of Set 1 | aklavik
# Processing Record 15 of Set 1 | cockeysville
# Processing Record 16 of Set 1 | kavieng
# Processing Record 17 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 1 | aporawan
# City not found. Skipping...
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | alofi
# Processing Record 22 of Set 1 | dingle
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | krasnoselkup
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | ponta do sol
# Processing Record 30 of Set 1 | carnarvon
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | mogadishu
# Processing Record 33 of Set 1 | hilo
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | sorland
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | saskylakh
# Processing Record 38 of Set 1 | oranjemund
# Processing Record 39 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 41 of Set 1 | mayo
# Processing Record 42 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 43 of Set 1 | severo-kurilsk
# Processing Record 44 of Set 1 | erzurum
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | hatillo
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | havre-saint-pierre
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | lagoa
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | saldanha
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | taoudenni
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | liaozhong
# Processing Record 8 of Set 2 | bathsheba
# Processing Record 9 of Set 2 | ushtobe
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | libreville
# Processing Record 12 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 2 | mahebourg
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | angoram
# Processing Record 16 of Set 2 | ust-nera
# Processing Record 17 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 2 | shinjo
# Processing Record 19 of Set 2 | chapais
# Processing Record 20 of Set 2 | byron bay
# Processing Record 21 of Set 2 | wajid
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | richards bay
# Processing Record 24 of Set 2 | fortuna
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | reserva
# Processing Record 28 of Set 2 | hamilton
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | yumen
# Processing Record 31 of Set 2 | goderich
# Processing Record 32 of Set 2 | dakar
# Processing Record 33 of Set 2 | kedrovyy
# Processing Record 34 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 2 | haines junction
# Processing Record 36 of Set 2 | thompson
# Processing Record 37 of Set 2 | ancud
# Processing Record 38 of Set 2 | fukue
# Processing Record 39 of Set 2 | bambous virieux
# Processing Record 40 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 2 | araure
# Processing Record 42 of Set 2 | san cristobal
# Processing Record 43 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 2 | havre
# Processing Record 45 of Set 2 | uzhur
# Processing Record 46 of Set 2 | bama
# Processing Record 47 of Set 2 | grand-santi
# Processing Record 48 of Set 2 | sioux lookout
# Processing Record 49 of Set 2 | vila franca do campo
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | chuy
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | vila velha
# Processing Record 4 of Set 3 | brigantine
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | ambilobe
# Processing Record 7 of Set 3 | kankon
# Processing Record 8 of Set 3 | buala
# Processing Record 9 of Set 3 | ganzhou
# Processing Record 10 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 3 | esperance
# Processing Record 12 of Set 3 | powell river
# Processing Record 13 of Set 3 | barstow
# Processing Record 14 of Set 3 | shellbrook
# Processing Record 15 of Set 3 | tomatlan
# Processing Record 16 of Set 3 | margate
# Processing Record 17 of Set 3 | veraval
# Processing Record 18 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 3 | lompoc
# Processing Record 20 of Set 3 | namibe
# Processing Record 21 of Set 3 | nantucket
# Processing Record 22 of Set 3 | hambantota
# Processing Record 23 of Set 3 | avarua
# Processing Record 24 of Set 3 | portland
# Processing Record 25 of Set 3 | narsaq
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | clyde river
# Processing Record 28 of Set 3 | pisco
# Processing Record 29 of Set 3 | buchanan
# Processing Record 30 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 3 | nioro
# Processing Record 32 of Set 3 | rudbar
# Processing Record 33 of Set 3 | ugoofaaru
# Processing Record 34 of Set 3 | seoul
# Processing Record 35 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 3 | manadhoo
# Processing Record 37 of Set 3 | brae
# Processing Record 38 of Set 3 | yavatmal
# Processing Record 39 of Set 3 | nome
# Processing Record 40 of Set 3 | vrises
# Processing Record 41 of Set 3 | alekseyevka
# Processing Record 42 of Set 3 | dikson
# Processing Record 43 of Set 3 | yunjinghong
# City not found. Skipping...
# Processing Record 44 of Set 3 | qafsah
# City not found. Skipping...
# Processing Record 45 of Set 3 | palmer
# Processing Record 46 of Set 3 | ucluelet
# Processing Record 47 of Set 3 | srebrenica
# Processing Record 48 of Set 3 | vestmanna
# Processing Record 49 of Set 3 | nhamunda
# Processing Record 50 of Set 3 | vostok
# Processing Record 1 of Set 4 | airai
# Processing Record 2 of Set 4 | kruisfontein
# Processing Record 3 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 4 of Set 4 | salalah
# Processing Record 5 of Set 4 | pevek
# Processing Record 6 of Set 4 | peniche
# Processing Record 7 of Set 4 | hobart
# Processing Record 8 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 4 | geraldton
# Processing Record 10 of Set 4 | altay
# Processing Record 11 of Set 4 | ngunguru
# Processing Record 12 of Set 4 | sawtell
# Processing Record 13 of Set 4 | lanxi
# Processing Record 14 of Set 4 | copiapo
# Processing Record 15 of Set 4 | khorramabad
# Processing Record 16 of Set 4 | lewiston
# Processing Record 17 of Set 4 | kieta
# Processing Record 18 of Set 4 | impfondo
# Processing Record 19 of Set 4 | dwarka
# Processing Record 20 of Set 4 | kaitangata
# Processing Record 21 of Set 4 | okhotsk
# Processing Record 22 of Set 4 | emba
# Processing Record 23 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 4 | shenzhen
# Processing Record 25 of Set 4 | cidreira
# Processing Record 26 of Set 4 | corinto
# Processing Record 27 of Set 4 | safranbolu
# Processing Record 28 of Set 4 | aleksandrov gay
# Processing Record 29 of Set 4 | ilebo
# Processing Record 30 of Set 4 | svetlogorsk
# Processing Record 31 of Set 4 | meulaboh
# Processing Record 32 of Set 4 | eyl
# Processing Record 33 of Set 4 | grindavik
# Processing Record 34 of Set 4 | amos
# Processing Record 35 of Set 4 | visnes
# Processing Record 36 of Set 4 | vardo
# Processing Record 37 of Set 4 | la ronge
# Processing Record 38 of Set 4 | yulara
# Processing Record 39 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 4 | iqaluit
# Processing Record 41 of Set 4 | ramsar
# Processing Record 42 of Set 4 | dingtao
# Processing Record 43 of Set 4 | diu
# Processing Record 44 of Set 4 | geresk
# City not found. Skipping...
# Processing Record 45 of Set 4 | shihezi
# Processing Record 46 of Set 4 | hualmay
# Processing Record 47 of Set 4 | dorado
# Processing Record 48 of Set 4 | sao filipe
# Processing Record 49 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 4 | nuuk
# Processing Record 1 of Set 5 | bandarbeyla
# Processing Record 2 of Set 5 | taburao
# City not found. Skipping...
# Processing Record 3 of Set 5 | saint-philippe
# Processing Record 4 of Set 5 | coihaique
# Processing Record 5 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 5 | berlevag
# Processing Record 7 of Set 5 | talara
# Processing Record 8 of Set 5 | mount gambier
# Processing Record 9 of Set 5 | harwich
# Processing Record 10 of Set 5 | faanui
# Processing Record 11 of Set 5 | ilulissat
# Processing Record 12 of Set 5 | inirida
# Processing Record 13 of Set 5 | camabatela
# Processing Record 14 of Set 5 | matagami
# Processing Record 15 of Set 5 | pendleton
# Processing Record 16 of Set 5 | cabo san lucas
# Processing Record 17 of Set 5 | gizo
# Processing Record 18 of Set 5 | flinders
# Processing Record 19 of Set 5 | dali
# Processing Record 20 of Set 5 | dalvik
# Processing Record 21 of Set 5 | te anau
# Processing Record 22 of Set 5 | kimbe
# Processing Record 23 of Set 5 | grand baie
# Processing Record 24 of Set 5 | port elizabeth
# Processing Record 25 of Set 5 | golden
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | bengkulu
# Processing Record 28 of Set 5 | san quintin
# Processing Record 29 of Set 5 | spentrup
# Processing Record 30 of Set 5 | port moresby
# Processing Record 31 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 5 | svetlaya
# Processing Record 33 of Set 5 | artyom
# Processing Record 34 of Set 5 | linhares
# Processing Record 35 of Set 5 | constitucion
# Processing Record 36 of Set 5 | hasaki
# Processing Record 37 of Set 5 | rosetta
# Processing Record 38 of Set 5 | zeya
# Processing Record 39 of Set 5 | menongue
# Processing Record 40 of Set 5 | northam
# Processing Record 41 of Set 5 | touros
# Processing Record 42 of Set 5 | leningradskiy
# Processing Record 43 of Set 5 | lalibela
# Processing Record 44 of Set 5 | katsuura
# Processing Record 45 of Set 5 | gornopravdinsk
# Processing Record 46 of Set 5 | jalu
# Processing Record 47 of Set 5 | baruun-urt
# Processing Record 48 of Set 5 | valparaiso
# Processing Record 49 of Set 5 | ibotirama
# Processing Record 50 of Set 5 | los llanos de aridane
# Processing Record 1 of Set 6 | akhtubinsk
# Processing Record 2 of Set 6 | pangnirtung
# Processing Record 3 of Set 6 | fairbanks
# Processing Record 4 of Set 6 | kenai
# Processing Record 5 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 6 | naantali
# Processing Record 7 of Set 6 | tiksi
# Processing Record 8 of Set 6 | la palma
# Processing Record 9 of Set 6 | olinda
# Processing Record 10 of Set 6 | namatanai
# Processing Record 11 of Set 6 | dunda
# Processing Record 12 of Set 6 | vyshestebliyevskaya
# Processing Record 13 of Set 6 | kaliganj
# Processing Record 14 of Set 6 | praia da vitoria
# Processing Record 15 of Set 6 | jumla
# Processing Record 16 of Set 6 | chumikan
# Processing Record 17 of Set 6 | san vicente
# Processing Record 18 of Set 6 | souillac
# Processing Record 19 of Set 6 | pochutla
# Processing Record 20 of Set 6 | codrington
# Processing Record 21 of Set 6 | plettenberg bay
# Processing Record 22 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 23 of Set 6 | ginda
# Processing Record 24 of Set 6 | ajdabiya
# Processing Record 25 of Set 6 | vuktyl
# Processing Record 26 of Set 6 | mount isa
# Processing Record 27 of Set 6 | manokwari
# Processing Record 28 of Set 6 | ixtapa
# Processing Record 29 of Set 6 | dasoguz
# Processing Record 30 of Set 6 | nanortalik
# Processing Record 31 of Set 6 | dongsheng
# Processing Record 32 of Set 6 | westport
# Processing Record 33 of Set 6 | rio gallegos
# Processing Record 34 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 6 | ola
# Processing Record 36 of Set 6 | tuktoyaktuk
# Processing Record 37 of Set 6 | iranshahr
# Processing Record 38 of Set 6 | shimoda
# Processing Record 39 of Set 6 | tasiilaq
# Processing Record 40 of Set 6 | panjab
# Processing Record 41 of Set 6 | balakhninskiy
# Processing Record 42 of Set 6 | sankeshwar
# Processing Record 43 of Set 6 | tecoanapa
# Processing Record 44 of Set 6 | amahai
# Processing Record 45 of Set 6 | alta floresta
# Processing Record 46 of Set 6 | phonhong
# Processing Record 47 of Set 6 | paamiut
# Processing Record 48 of Set 6 | elko
# Processing Record 49 of Set 6 | bubaque
# Processing Record 50 of Set 6 | ponta delgada
# Processing Record 1 of Set 7 | sergeyevka
# Processing Record 2 of Set 7 | luoyang
# Processing Record 3 of Set 7 | santa rosa
# Processing Record 4 of Set 7 | la romana
# Processing Record 5 of Set 7 | birao
# Processing Record 6 of Set 7 | richmond
# Processing Record 7 of Set 7 | hofn
# Processing Record 8 of Set 7 | kosai
# Processing Record 9 of Set 7 | manoel urbano
# Processing Record 10 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 7 | cabedelo
# Processing Record 12 of Set 7 | koszalin
# Processing Record 13 of Set 7 | ginir
# Processing Record 14 of Set 7 | carndonagh
# Processing Record 15 of Set 7 | bethel
# Processing Record 16 of Set 7 | kaoma
# Processing Record 17 of Set 7 | lebu
# Processing Record 18 of Set 7 | imbituba
# Processing Record 19 of Set 7 | leticia
# Processing Record 20 of Set 7 | sohag
# Processing Record 21 of Set 7 | pemangkat
# Processing Record 22 of Set 7 | kamyaran
# Processing Record 23 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 24 of Set 7 | mocuba
# Processing Record 25 of Set 7 | tokur
# Processing Record 26 of Set 7 | marsh harbour
# Processing Record 27 of Set 7 | khawhai
# Processing Record 28 of Set 7 | vila do maio
# Processing Record 29 of Set 7 | inhambane
# Processing Record 30 of Set 7 | griffith
# Processing Record 31 of Set 7 | puerto escondido
# Processing Record 32 of Set 7 | maningrida
# Processing Record 33 of Set 7 | luderitz
# Processing Record 34 of Set 7 | raudeberg
# Processing Record 35 of Set 7 | chepareria
# Processing Record 36 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 37 of Set 7 | la maddalena
# Processing Record 38 of Set 7 | rabaul
# Processing Record 39 of Set 7 | kodiak
# Processing Record 40 of Set 7 | lar
# Processing Record 41 of Set 7 | saint quentin
# City not found. Skipping...
# Processing Record 42 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 7 | ust-kulom
# Processing Record 44 of Set 7 | vao
# Processing Record 45 of Set 7 | kozhva
# Processing Record 46 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 7 | kloulklubed
# Processing Record 48 of Set 7 | tilichiki
# Processing Record 49 of Set 7 | yashkul
# Processing Record 50 of Set 7 | waddan
# Processing Record 1 of Set 8 | sisophon
# Processing Record 2 of Set 8 | singida
# Processing Record 3 of Set 8 | radom
# Processing Record 4 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 5 of Set 8 | porbandar
# Processing Record 6 of Set 8 | imeni poliny osipenko
# Processing Record 7 of Set 8 | port hedland
# Processing Record 8 of Set 8 | nawa
# Processing Record 9 of Set 8 | maravilha
# Processing Record 10 of Set 8 | awbari
# Processing Record 11 of Set 8 | shingu
# Processing Record 12 of Set 8 | puerto del rosario
# Processing Record 13 of Set 8 | petatlan
# Processing Record 14 of Set 8 | nikolskoye
# Processing Record 15 of Set 8 | mehamn
# Processing Record 16 of Set 8 | naze
# Processing Record 17 of Set 8 | aksu
# Processing Record 18 of Set 8 | opobo
# City not found. Skipping...
# Processing Record 19 of Set 8 | aras
# Processing Record 20 of Set 8 | palauig
# Processing Record 21 of Set 8 | teknaf
# Processing Record 22 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 8 | cheremshan
# Processing Record 24 of Set 8 | tazovskiy
# Processing Record 25 of Set 8 | sitka
# Processing Record 26 of Set 8 | oussouye
# Processing Record 27 of Set 8 | conde
# Processing Record 28 of Set 8 | charlestown
# Processing Record 29 of Set 8 | porto novo
# Processing Record 30 of Set 8 | hebertville
# City not found. Skipping...
# Processing Record 31 of Set 8 | victoria
# Processing Record 32 of Set 8 | nicoya
# Processing Record 33 of Set 8 | chickasha
# Processing Record 34 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 8 | yarim
# Processing Record 36 of Set 8 | eydhafushi
# Processing Record 37 of Set 8 | faya
# Processing Record 38 of Set 8 | coquimbo
# Processing Record 39 of Set 8 | jefferson city
# Processing Record 40 of Set 8 | kaspiysk
# Processing Record 41 of Set 8 | trud
# Processing Record 42 of Set 8 | singaparna
# Processing Record 43 of Set 8 | mullaitivu
# City not found. Skipping...
# Processing Record 44 of Set 8 | ahipara
# Processing Record 45 of Set 8 | mococa
# Processing Record 46 of Set 8 | otane
# Processing Record 47 of Set 8 | mankera
# Processing Record 48 of Set 8 | lorengau
# Processing Record 49 of Set 8 | sambava
# Processing Record 50 of Set 8 | chokurdakh
# Processing Record 1 of Set 9 | oroville
# Processing Record 2 of Set 9 | nouadhibou
# Processing Record 3 of Set 9 | bairiki
# Processing Record 4 of Set 9 | kempsey
# Processing Record 5 of Set 9 | huntingdon
# Processing Record 6 of Set 9 | iwaki
# Processing Record 7 of Set 9 | avera
# Processing Record 8 of Set 9 | port lincoln
# Processing Record 9 of Set 9 | kota bahru
# Processing Record 10 of Set 9 | kismayo
# Processing Record 11 of Set 9 | wasilla
# Processing Record 12 of Set 9 | shumskiy
# Processing Record 13 of Set 9 | mormugao
# Processing Record 14 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 9 | honningsvag
# Processing Record 16 of Set 9 | broken hill
# Processing Record 17 of Set 9 | nuoro
# Processing Record 18 of Set 9 | mana
# Processing Record 19 of Set 9 | santa cruz
# Processing Record 20 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 21 of Set 9 | miri
# Processing Record 22 of Set 9 | plonsk
# Processing Record 23 of Set 9 | sinop
# Processing Record 24 of Set 9 | setermoen
# Processing Record 25 of Set 9 | ishigaki
# Processing Record 26 of Set 9 | agadez
# Processing Record 27 of Set 9 | jizan
# Processing Record 28 of Set 9 | manzil salim
# Processing Record 29 of Set 9 | broome
# Processing Record 30 of Set 9 | moose factory
# Processing Record 31 of Set 9 | san patricio
# Processing Record 32 of Set 9 | kavaratti
# Processing Record 33 of Set 9 | sola
# Processing Record 34 of Set 9 | les cayes
# Processing Record 35 of Set 9 | kungurtug
# Processing Record 36 of Set 9 | gwanda
# Processing Record 37 of Set 9 | cockburn town
# Processing Record 38 of Set 9 | bilibino
# Processing Record 39 of Set 9 | pangody
# Processing Record 40 of Set 9 | severobaykalsk
# Processing Record 41 of Set 9 | trzebiatow
# Processing Record 42 of Set 9 | atambua
# Processing Record 43 of Set 9 | sobolevo
# Processing Record 44 of Set 9 | nizhnevartovsk
# Processing Record 45 of Set 9 | saint anthony
# Processing Record 46 of Set 9 | lakselv
# Processing Record 47 of Set 9 | kalmunai
# Processing Record 48 of Set 9 | alice springs
# Processing Record 49 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 9 | nampula
# Processing Record 1 of Set 10 | angra
# City not found. Skipping...
# Processing Record 2 of Set 10 | kaitong
# Processing Record 3 of Set 10 | arraial do cabo
# Processing Record 4 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 5 of Set 10 | emerald
# Processing Record 6 of Set 10 | ostrovnoy
# Processing Record 7 of Set 10 | rio grande
# Processing Record 8 of Set 10 | imbituva
# Processing Record 9 of Set 10 | bilma
# Processing Record 10 of Set 10 | arlit
# Processing Record 11 of Set 10 | nador
# Processing Record 12 of Set 10 | nelson bay
# Processing Record 13 of Set 10 | salamiyah
# Processing Record 14 of Set 10 | dunedin
# Processing Record 15 of Set 10 | poum
# Processing Record 16 of Set 10 | kamenka
# Processing Record 17 of Set 10 | greece
# Processing Record 18 of Set 10 | pativilca
# Processing Record 19 of Set 10 | gilazi
# City not found. Skipping...
# Processing Record 20 of Set 10 | evanston
# Processing Record 21 of Set 10 | hervey bay
# Processing Record 22 of Set 10 | rorvik
# Processing Record 23 of Set 10 | lakes entrance
# Processing Record 24 of Set 10 | fort-shevchenko
# Processing Record 25 of Set 10 | quang ngai
# Processing Record 26 of Set 10 | kalmar
# Processing Record 27 of Set 10 | rawson
# Processing Record 28 of Set 10 | tezu
# Processing Record 29 of Set 10 | arcos de la frontera
# Processing Record 30 of Set 10 | biltine
# Processing Record 31 of Set 10 | jawhar
# Processing Record 32 of Set 10 | lokoja
# Processing Record 33 of Set 10 | tacuarembo
# Processing Record 34 of Set 10 | atar
# Processing Record 35 of Set 10 | ambulu
# Processing Record 36 of Set 10 | jerome
# Processing Record 37 of Set 10 | thohoyandou
# Processing Record 38 of Set 10 | port blair
# Processing Record 39 of Set 10 | kirakira
# Processing Record 40 of Set 10 | porto velho
# Processing Record 41 of Set 10 | cubuk
# Processing Record 42 of Set 10 | safwah
# City not found. Skipping...
# Processing Record 43 of Set 10 | guerrero negro
# Processing Record 44 of Set 10 | lepa
# Processing Record 45 of Set 10 | tuatapere
# Processing Record 46 of Set 10 | cam ranh
# Processing Record 47 of Set 10 | anloga
# Processing Record 48 of Set 10 | egvekinot
# Processing Record 49 of Set 10 | nishihara
# Processing Record 50 of Set 10 | noumea
# Processing Record 1 of Set 11 | alihe
# Processing Record 2 of Set 11 | mackay
# Processing Record 3 of Set 11 | port augusta
# Processing Record 4 of Set 11 | stornoway
# Processing Record 5 of Set 11 | tual
# Processing Record 6 of Set 11 | areado
# Processing Record 7 of Set 11 | north bend
# Processing Record 8 of Set 11 | sumter
# Processing Record 9 of Set 11 | saint joseph
# Processing Record 10 of Set 11 | jepelacio
# Processing Record 11 of Set 11 | khani
# Processing Record 12 of Set 11 | cascais
# Processing Record 13 of Set 11 | bethanien
# Processing Record 14 of Set 11 | padang
# Processing Record 15 of Set 11 | belaya gora
# Processing Record 16 of Set 11 | mandalgovi
# Processing Record 17 of Set 11 | talnakh
# Processing Record 18 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 19 of Set 11 | north platte
# Processing Record 20 of Set 11 | hobyo
# Processing Record 21 of Set 11 | tautira
# Processing Record 22 of Set 11 | kholtoson
# Processing Record 23 of Set 11 | lucatan
# City not found. Skipping...
# Processing Record 24 of Set 11 | esna
# Processing Record 25 of Set 11 | verkhniye kigi
# Processing Record 26 of Set 11 | wahiawa
# Processing Record 27 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 28 of Set 11 | maragogi
# Processing Record 29 of Set 11 | winslow
# Processing Record 30 of Set 11 | antofagasta
# Processing Record 31 of Set 11 | khash
# Processing Record 32 of Set 11 | dibaya
# City not found. Skipping...
# Processing Record 33 of Set 11 | valleyview
# Processing Record 34 of Set 11 | husavik
# Processing Record 35 of Set 11 | dudinka
# Processing Record 36 of Set 11 | monrovia
# Processing Record 37 of Set 11 | catuday
# Processing Record 38 of Set 11 | necochea
# Processing Record 39 of Set 11 | harper
# Processing Record 40 of Set 11 | canto do buriti
# Processing Record 41 of Set 11 | krasnopavlivka
# Processing Record 42 of Set 11 | poronaysk
# Processing Record 43 of Set 11 | mulanje
# Processing Record 44 of Set 11 | camacha
# Processing Record 45 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 11 | poli
# Processing Record 47 of Set 11 | katangli
# Processing Record 48 of Set 11 | kiama
# Processing Record 49 of Set 11 | usak
# Processing Record 50 of Set 11 | burnie
# Processing Record 1 of Set 12 | adrar
# Processing Record 2 of Set 12 | acapulco
# Processing Record 3 of Set 12 | miyazu
# Processing Record 4 of Set 12 | bowen
# Processing Record 5 of Set 12 | tessalit
# Processing Record 6 of Set 12 | chateau-thierry
# Processing Record 7 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 12 | bani
# Processing Record 9 of Set 12 | grand gaube
# Processing Record 10 of Set 12 | hurghada
# Processing Record 11 of Set 12 | gweru
# Processing Record 12 of Set 12 | assiniboia
# Processing Record 13 of Set 12 | samarai
# Processing Record 14 of Set 12 | burkhala
# City not found. Skipping...
# Processing Record 15 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 16 of Set 12 | spirit river
# Processing Record 17 of Set 12 | gasa
# Processing Record 18 of Set 12 | moiyabana
# City not found. Skipping...
# Processing Record 19 of Set 12 | teahupoo
# Processing Record 20 of Set 12 | nakamura
# Processing Record 21 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 22 of Set 12 | slavonski brod
# Processing Record 23 of Set 12 | placido de castro
# Processing Record 24 of Set 12 | muscat
# Processing Record 25 of Set 12 | karratha
# Processing Record 26 of Set 12 | coalcoman
# City not found. Skipping...
# Processing Record 27 of Set 12 | kristiinankaupunki
# Processing Record 28 of Set 12 | altamira
# Processing Record 29 of Set 12 | dohar
# Processing Record 30 of Set 12 | hadrut
# Processing Record 31 of Set 12 | belmonte
# Processing Record 32 of Set 12 | edson
# Processing Record 33 of Set 12 | beringovskiy
# Processing Record 34 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 35 of Set 12 | saratov
# Processing Record 36 of Set 12 | gweta
# Processing Record 37 of Set 12 | mawlaik
# Processing Record 38 of Set 12 | yanam
# Processing Record 39 of Set 12 | shelburne
# Processing Record 40 of Set 12 | shangrao
# Processing Record 41 of Set 12 | smoky lake
# Processing Record 42 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 43 of Set 12 | banepa
# Processing Record 44 of Set 12 | nuevo casas grandes
# Processing Record 45 of Set 12 | ambo
# Processing Record 46 of Set 12 | kailua
# Processing Record 47 of Set 12 | rocha
# Processing Record 48 of Set 12 | ust-uda
# Processing Record 49 of Set 12 | zhigansk
# Processing Record 50 of Set 12 | totskoye
# Processing Record 1 of Set 13 | sechura
# Processing Record 2 of Set 13 | sao felix do xingu
# Processing Record 3 of Set 13 | neijiang
# Processing Record 4 of Set 13 | marzuq
# Processing Record 5 of Set 13 | upata
# Processing Record 6 of Set 13 | springfield
# Processing Record 7 of Set 13 | sorong
# Processing Record 8 of Set 13 | alghero
# Processing Record 9 of Set 13 | nabire
# Processing Record 10 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 11 of Set 13 | wilmington island
# Processing Record 12 of Set 13 | buluang
# Processing Record 13 of Set 13 | serenje
# Processing Record 14 of Set 13 | sohbatpur
# Processing Record 15 of Set 13 | sur
# Processing Record 16 of Set 13 | beba
# Processing Record 17 of Set 13 | thinadhoo
# Processing Record 18 of Set 13 | hami
# Processing Record 19 of Set 13 | bacolod
# Processing Record 20 of Set 13 | turbat
# Processing Record 21 of Set 13 | canchungo
# Processing Record 22 of Set 13 | fort carson
# Processing Record 23 of Set 13 | tolaga bay
# Processing Record 24 of Set 13 | sinnamary
# Processing Record 25 of Set 13 | adrian
# Processing Record 26 of Set 13 | wageningen
# Processing Record 27 of Set 13 | jaca
# Processing Record 28 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 13 | guatire
# Processing Record 30 of Set 13 | swiecie
# Processing Record 31 of Set 13 | akdepe
# Processing Record 32 of Set 13 | kahului
# Processing Record 33 of Set 13 | mitsamiouli
# Processing Record 34 of Set 13 | nassau
# Processing Record 35 of Set 13 | palmeira das missoes
# Processing Record 36 of Set 13 | iberia
# Processing Record 37 of Set 13 | chama
# Processing Record 38 of Set 13 | itacarambi
# Processing Record 39 of Set 13 | auki
# Processing Record 40 of Set 13 | kupang
# Processing Record 41 of Set 13 | vysokogornyy
# Processing Record 42 of Set 13 | kabelvag
# Processing Record 43 of Set 13 | athabasca
# Processing Record 44 of Set 13 | lazaro cardenas
# Processing Record 45 of Set 13 | maarianhamina
# Processing Record 46 of Set 13 | belyy yar
# Processing Record 47 of Set 13 | hovd
# Processing Record 48 of Set 13 | preobrazheniye
# Processing Record 49 of Set 13 | port macquarie
# Processing Record 50 of Set 13 | gannan
# Processing Record 1 of Set 14 | machilipatnam
# Processing Record 2 of Set 14 | marawi
# Processing Record 3 of Set 14 | nipawin
# Processing Record 4 of Set 14 | teguise
# Processing Record 5 of Set 14 | muswellbrook
# Processing Record 6 of Set 14 | yen bai
# Processing Record 7 of Set 14 | sayyan
# Processing Record 8 of Set 14 | natal
# Processing Record 9 of Set 14 | ambovombe
# Processing Record 10 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 11 of Set 14 | bellegarde-sur-valserine
# Processing Record 12 of Set 14 | bousse
# Processing Record 13 of Set 14 | oga
# Processing Record 14 of Set 14 | yangambi
# Processing Record 15 of Set 14 | saint-pierre
# Processing Record 16 of Set 14 | delijan
# Processing Record 17 of Set 14 | kluczbork
# Processing Record 18 of Set 14 | kandrian
# Processing Record 19 of Set 14 | samfya
# Processing Record 20 of Set 14 | tabas
# Processing Record 21 of Set 14 | zhuhai
# Processing Record 22 of Set 14 | sillod
# Processing Record 23 of Set 14 | san juan
# Processing Record 24 of Set 14 | gurgentepe
# Processing Record 25 of Set 14 | santa fe
# Processing Record 26 of Set 14 | aasiaat
# Processing Record 27 of Set 14 | yozgat
# Processing Record 28 of Set 14 | olafsvik
# Processing Record 29 of Set 14 | yarmouth
# Processing Record 30 of Set 14 | alekseyevsk
# Processing Record 31 of Set 14 | puerto cabezas
# Processing Record 32 of Set 14 | comodoro rivadavia
# Processing Record 33 of Set 14 | along
# Processing Record 34 of Set 14 | batagay-alyta
# Processing Record 35 of Set 14 | kulhudhuffushi
# Processing Record 36 of Set 14 | moron
# Processing Record 37 of Set 14 | vanavara
# Processing Record 38 of Set 14 | coahuayana
# Processing Record 39 of Set 14 | leopold
# Processing Record 40 of Set 14 | oksfjord
# Processing Record 41 of Set 14 | mooi river
# City not found. Skipping...
# Processing Record 42 of Set 14 | tabou
# Processing Record 43 of Set 14 | the pas
# Processing Record 44 of Set 14 | podor
# Processing Record 45 of Set 14 | vilhena
# Processing Record 46 of Set 14 | road town
# Processing Record 47 of Set 14 | panixtlahuaca
# City not found. Skipping...
# Processing Record 48 of Set 14 | pilar
# Processing Record 49 of Set 14 | duliagaon
# Processing Record 50 of Set 14 | akyab
# Processing Record 1 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 15 | nizhnyaya salda
# Processing Record 3 of Set 15 | san carlos de bariloche
# Processing Record 4 of Set 15 | eureka
# Processing Record 5 of Set 15 | sebeta
# Processing Record 6 of Set 15 | daultala
# Processing Record 7 of Set 15 | xilagani
# Processing Record 8 of Set 15 | beira
# Processing Record 9 of Set 15 | kjollefjord
# Processing Record 10 of Set 15 | bereda
# Processing Record 11 of Set 15 | chengde
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Step 7 add the data to a new DataFrame. 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   New Norfolk      AU -42.7826  147.0587     45.91        56          59
# 1     Jamestown      US  42.0970  -79.2353     72.99        88          40
# 2       Qaanaaq      GL  77.4840  -69.3632     41.11        66         100
# 3   East London      ZA -33.0153   27.9116     52.81        69           0
# 4    Georgetown      MY   5.4112  100.3354     82.89        89          20
# 5         Kapaa      US  22.0752 -159.3190     84.18        80          75
# 6   Deputatskiy      RU  69.3000  139.9000     53.13        55          33
# 7  Puerto Ayora      EC  -0.7393  -90.3518     72.55        84          11
# 8   Provideniya      RU  64.3833 -173.3000     47.71        98         100
# 9     Sept-Iles      CA  50.2001  -66.3821     62.26        92          40
#
#    Wind Speed Current Description
# 0       11.34       broken clouds
# 1        5.01    scattered clouds
# 2        2.21     overcast clouds
# 3       12.37           clear sky
# 4        2.30          few clouds
# 5        3.00          light rain
# 6        7.56    scattered clouds
# 7        7.00          few clouds
# 8       13.04          light rain
# 9        5.01    scattered clouds
